# %%
import pandas as pd

# %%
twt = pd.read_csv('set//twt_bill2.csv')

# %%
twt[:27]
# Out:
#            dates                    ID  \
# 0   2023년 5월 15일  Bill Gates@BillGates
# 1   2023년 5월 12일  Bill Gates@BillGates
# 2   2023년 5월 12일  Bill Gates@BillGates
# 3   2023년 5월 12일  Bill Gates@BillGates
# 4   2023년 5월 11일  Bill Gates@BillGates
# 5   2023년 5월 11일  Bill Gates@BillGates
# 6   2023년 5월 10일  Bill Gates@BillGates
# 7   2023년 5월 10일  Bill Gates@BillGates
# 8    2023년 5월 9일  Bill Gates@BillGates
# 9    2023년 5월 9일  Bill Gates@BillGates
# 10   2023년 5월 8일  Bill Gates@BillGates
# 11   2023년 5월 6일  Bill Gates@BillGates
# 12   2023년 5월 6일  Bill Gates@BillGates
# 13   2023년 5월 4일  Bill Gates@BillGates
# 14  2023년 3월 30일  Bill Gates@BillGates
# 15  2023년 3월 29일  Bill Gates@BillGates
# 16  2023년 3월 27일  Bill Gates@BillGates
# 17  2023년 3월 27일  Bill Gates@BillGates
# 18  2023년 3월 25일  Bill Gates@BillGates
# 19  2023년 3월 23일  Bill Gates@BillGates
# 20  2023년 3월 23일  Bill Gates@BillGates
# 21  2023년 3월 23일  Bill Gates@BillGates
# 22  2023년 3월 22일  Bill Gates@BillGates
# ...

# %%
twt_alevie.loc[:26,'dates'] = '2024년 ' + twt_alevie.loc[:26,'dates']

# %%
twt_alevie.to_csv('twt_alevie.csv', index = False)

# %%
pd.df

# %%
twt_elon_data = []

for file_path in twt_elon_path:
    data = pd.read_csv(file_path, low_memory=False)
    data = data.loc[::-1].reset_index(drop=True)
    twt_elon_data.append(data)
    
twt_elon_data[:5]

# %%
twt_alevie[dates]
# Out:
#             dates                 ID  \
# 0          2월 27일  Aaron Levie@levie
# 1          2월 26일  Aaron Levie@levie
# 2          2월 25일  Aaron Levie@levie
# 3          2월 25일  Aaron Levie@levie
# 4          2월 24일  Aaron Levie@levie
# ..            ...                ...
# 252  2022년 3월 16일  Aaron Levie@levie
# 253  2022년 3월 13일  Aaron Levie@levie
# 254  2022년 3월 11일  Aaron Levie@levie
# 255  2022년 3월 10일  Aaron Levie@levie
# 256  2022년 3월 10일  Aaron Levie@levie
#
#                                                content   rt  like
# 0    For context, Netflix could ship you their enti...   69   434
# 1    Startups tend to win in spaces where the incum...  165   894
# 2    People’s understanding of business is funny. B...   30   251
# 3    How could you passionately hate people this much.   71   607
# 4    We’re beta testing an AI feature internally at...   39   232
# ..                                                 ...  ...   ...
# ...

# %%
twt_alevie_1 = twt_alevie.iloc[0,:]
df['Date'] = '2024년' + df['Date']

# %%
column_row = ['Date','name','tweet','retweet','like']
g = pd.concat([twt_alevie,column_row], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 column_row = ['Date','name','tweet','retweet','like']
# ----> 2 g = pd.concat([twt_alevie,column_row], ignore_index=True)
#
# File c:\Users\mit16\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# ...

# %%
twt_alevie_1 = twt_alevie[.iloc[0,:]]
df['Date'] = '2024년' + df['Date']
