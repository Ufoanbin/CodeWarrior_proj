# %%
from selenium import webdriver
import pickle
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
from selenium.webdriver.support import expected_conditions
import time 
email =''
id = ''
password =''

options = Options()
options.add_argument("start-maximized")

webdriver_service = Service('C:\webdrivers\chromedriver.exe')
driver = webdriver.Chrome()
url = 'https://twitter.com/search?q=from%3Aelonmusk%2C%20Tesla%20since%3A2019-01-01%20until%3A2024-01-01%20-filter%3Areplies&src=recent_search_click&f=live'
driver.get(url)
wait = WebDriverWait(driver, 20)

wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '[autocomplete="username"]'))).send_keys("email")
driver.find_element(By.CSS_SELECTOR, '[class="css-175oi2r r-sdzlij r-1phboty r-rs99b7 r-lrvibr r-ywje51 r-usiww2 r-13qz1uu r-2yi16 r-1qi8awa r-ymttw5 r-1loqt21 r-o7ynqc r-6416eg r-1ny4l3l"]').click()

# driver.find_element(By.CSS_SELECTOR, '[data-testid="LoginForm_Login_Button"]').click()

# 비밀번호 자주 틀렸을때 추가 접속 코드
 
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '[autocomplete="on"]'))).send_keys("id")
 
driver.find_element(By.CSS_SELECTOR, '[data-testid="ocfEnterTextNextButton"]').click()

cookies = driver.get_cookies()
pickle.dump(cookies, open("cookies.pkl", "wb"))


ceo_link_list = []
ceo_link_list.append("https://twitter.com/search?q=from%3A%40LisaSu%20since%3A2020-01-01&src=typed_query&f=live")


cookies = pickle.load(open("cookies.pkl", "rb")) 
 

twit_df = {}
twttxt = []
style="text-overflow: unset;"

pause_time = 2
last_height = driver.execute_script("return document.body.scrollHeight")
datetime_set = []
remover = []
for cll in ceo_link_list:
    driver.get(cll)
  

    try:
        WebDriverWait(driver, 60).until(expected_conditions.presence_of_element_located((By.CSS_SELECTOR, '[data-testid="tweet"]')))

    except WebDriverException:
        print("Something happened. No tweets loaded")
    
    while True:
        # # Scroll down to bottom
        # driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # # Wait to load page
        # time.sleep(pause_time)

        # # Calculate new scroll height and compare with last scroll height
        # new_height = driver.execute_script("return document.body.scrollHeight")
        # if new_height == last_height:
        #     break
        # last_height = new_height
        html_content = driver.page_source
        soup = BeautifulSoup(html_content, 'html.parser')

        twts = soup.find_all(attrs={"data-testid": "tweetText"})
        removes = soup.find_all(attrs={"class": "css-1rynq56 r-8akbws r-krxsd3 r-dnmrzs r-1udh08x r-bcqeeo r-qvutc0 r-37j5jr r-a023e6 r-rjixqe r-16dba41 r-bnwqim r-14gqq1x"})
        # for t in soup.select('a>time'):
        #     datetime = t.get('datetime')
        #     time.append(datetime)
            # tag / element 
            # print(t)

            # text
            # print(t.text)

            # attribute value
            # print(t.get('datetime'))
        ts = soup.select('a>time')
        datetime_set.append(ts)
        # datetime = [t.get('datetime') for t in ts]
            
        for ht in twts:
            print('트위터 트윗내용')
            text = ht.get_text()
            print(text)
            print('\n\n\n')
            twttxt.append(text)
        for remove in removes:
            r_text = remove.get_text()
            remover.append(r_text)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(pause_time)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
# Out:
# 트위터 트윗내용
# Thanks for the collaboration and feedback.  We are all in to get you a good solution.  Team is on it.
#
#
#
#
# 트위터 트윗내용
# Fantastic time with our Americas @AMD sales team as they kicked off the year. Congratulations to our award winners and looking forward to all we will do together in 2024!
#
#
#
#
# 트위터 트윗내용
# This week marks the two year anniversary of Xilinx joining the @AMD family.  Thanks to the @AMDembedded team for the fantastic momentum.  Loved my gift  - another great chip to add to my collection - the largest and most complex FPGA ever built - Versal Premium - being used now…
#
#
#
#
# 트위터 트윗내용
# Happy Lunar New Year!  Wishing our @AMD family and friends great health, happiness and prosperity in the Year of the Dragon!
#
#
#
#
# 트위터 트윗내용
# Really enjoyed  spending some time with @kevin_scott talking about tech, AI and much more.  Thanks for having me!
#
#
#
#
# 트위터 트윗내용
# ...

# %%
remover
# Out:
# ['We’re kicking off the New Year on #BehindtheTech with a wide-ranging conversation with @LisaSu, Chair and CEO of @AMD, from her upbringing and early interest in engineering to her role today leading one of the fastest growing semiconductor companies in the world. Take a listen.',
#  'We couldn’t have asked for a better guest to kick off season two of The Moment with @RyanPatelGlobal than @LisaSu, CEO of @AMD. Lisa talked with us about AMD’s leading role in the future of #AI and so much more. Watch on YouTube for more: https://bit.ly/3tygWVZ #HPTheMoment',
#  'Excited to announce a HUGE secret with @LisaSu: @LaminiAI has been building LLMs on @AMD GPUs *in production* for over the past year!\n\nWe’ve made running LLMs on AMD super easy and a highly competitive option through our LLM Superstation, available now at ~10x lower cost than…',
# ...

# %%
from selenium import webdriver
import pickle
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
from selenium.webdriver.support import expected_conditions
import time 
import

stock = read_csv(r'C:\Users\mit16\Desktop\project\TeamProject_CodeWarrior\dataSet\stock/*')
