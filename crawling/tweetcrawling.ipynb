# %%
팔로워 많은 CEO 리스트
#####'아이디' : '@jack', '주식기호' : 'TWTR', '이름':'Jack Dorsey', '내용' : '트위터 전 최고경영자'### 상장폐지

'아이디' : '@reedhastings', '주식기호' : 'NFLX', '이름':'Reed Hastings', '내용' : ' 넷플릭스 CEO'
'아이디' : '@JohnLegere', '주식기호' : 'TMUS', '이름':'John Legere', '내용' : ' T-Mobile US 의 사장'
'아이디' : '@elonmusk', '주식기호' : 'TSLA', '이름':'Elon Musk', '내용':'Tesla Motors CEO'
'아이디' : '@tim_cock', '주식기호' : 'AAPL', '이름' : 'Tim Cook', '내용' : 'Apple CEO'
'아이디' : '@richardbranson', '주식기호' : 'SPCE', '이름' : 'Richard Branson', '내용' : 'Virgin Group CEO'
'아이디' : '@BillGates', '주식기호' : 'MSFT', '이름' : 'Bill Gates', '내용' : 'Microsoft Corporation CEO'
'아이디' : '@Carl_C_Icahn', '주식기호' : 'IEP', '이름' : 'Carl Icahn', '내용' : 'Icahn Enterprises LP CEO'
'아이디' : '@LisaSu', '주식기호' : 'AMD', '이름' : 'Mark Cuban', '내용' : 'AMD CEO'
'아이디' : '@levie', '주식기호' : 'BOX', '이름' : 'Aaron Levie', '내용' : 'BOX CEO'
'아이디' : '@bchesky', '주식기호' : 'ABNB', '이름' : 'Brian Chesky', '내용' : 'Airbnb CEO'

# %%
from selenium import webdriver
import pickle
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
from selenium.webdriver.support import expected_conditions
import time 

options = Options()
options.add_argument("start-maximized")

webdriver_service = Service('C:\webdrivers\chromedriver.exe')
driver = webdriver.Chrome()
url = 'https://twitter.com/search?q=from%3Aelonmusk%2C%20Tesla%20since%3A2019-03-10%20until%3A2024-03-10%20-filter%3Areplies&src=typed_query&f=live'
driver.get(url)
wait = WebDriverWait(driver, 20)

cookies = driver.get_cookies()
pickle.dump(cookies, open("cookies.pkl", "wb"))


ceo_link_list = []
ceo_link_list.append("https://twitter.com/search?q=from%3Aelonmusk%2C%20Tesla%20since%3A2019-03-10%20until%3A2024-03-10%20-filter%3Areplies&src=typed_query&f=live")


cookies = pickle.load(open("cookies.pkl", "rb")) 
 

twit_df = {}
textlist = []
style="text-overflow: unset;"

pause_time = 2
last_height = driver.execute_script("return document.body.scrollHeight")
datetime_set = []
remover = []
for cll in ceo_link_list:
    driver.get(cll)
    try:
        WebDriverWait(driver, 60).until(expected_conditions.presence_of_element_located((By.CSS_SELECTOR, '[data-testid="tweet"]')))
    except WebDriverException:
        print("Something happened. No tweets loaded") 
    while True:
        # # Scroll down to bottom
        # driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # # Wait to load page
        # time.sleep(pause_time)

        # # Calculate new scroll height and compare with last scroll height
        # new_height = driver.execute_script("return document.body.scrollHeight")
        # if new_height == last_height:
        #     break
        # last_height = new_height
        html_content = driver.page_source
        soup = BeautifulSoup(html_content, 'html.parser')
        twts = soup.find_all(attrs={"data-testid": "tweetText"})
        removes = soup.find_all(attrs={"class": "css-1rynq56 r-8akbws r-krxsd3 r-dnmrzs r-1udh08x r-bcqeeo r-qvutc0 r-37j5jr r-a023e6 r-rjixqe r-16dba41 r-bnwqim r-14gqq1x"}) # 인용트윗
        # for t in soup.select('a>time'):
        #     datetime = t.get('datetime')
        #     time.append(datetime)
            # tag / element 
            # print(t)
            # text
            # print(t.text)
            # attribute value
            # print(t.get('datetime'))
        ts = soup.select('a>time')
        datetime_set.append(ts)
        # datetime = [t.get('datetime') for t in ts]
        
        for ht in twts:
            textlist.append(ht.get_text())  
        for remove in removes:
            r_text = remove.get_text()
            remover.append(r_text)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(pause_time)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# %%
import pandas as pd
twtdf = pd.DataFrame(columns=['username', 'data', 'tweet', 'retweets', 'likes'])
twtdf = pd.DataFrame(textlist, columns=['tweet'])
twtdf
# Out:
#                                                  tweet
# 0                                    Tesla is hardcore
# 1                                            Lights On
# 2                                  Car talk with Tesla
# 3    All-new Model 3 with Franz @woodhaus2 & Lars @...
# 4    Still wasting time reading 100-page documents?...
# ..                                                 ...
# 251  To be clear, I’m always driving, but I think I...
# 252  Stars into pesto 유광하드케이스\n\n깔끔하고 심플한 케이스 구경오세요...
# 253  Please note prices on all Tesla inventory cars...
# 254           New Tesla referral program just released
# 255  Tesla car prices go up ~3% next week, except f...
#
# [256 rows x 1 columns]

# %%
ceo_list = [{'아이디' : '@reedhastings', '주식기호' : 'NFLX', '이름':'Reed Hastings', '내용' : ' 넷플릭스 CEO'},
{'아이디' : '@JohnLegere', '주식기호' : 'TMUS', '이름':'John Legere', '내용' : ' T-Mobile US 의 사장'},
{'아이디' : '@elonmusk', '주식기호' : 'TSLA', '이름':'Elon Musk', '내용':'Tesla Motors CEO'},
{'아이디' : '@tim_cock', '주식기호' : 'AAPL', '이름' : 'Tim Cook', '내용' : 'Apple CEO'},
{'아이디' : '@richardbranson', '주식기호' : 'SPCE', '이름' : 'Richard Branson', '내용' : 'Virgin Group CEO'},
{'아이디' : '@BillGates', '주식기호' : 'MSFT', '이름' : 'Bill Gates', '내용' : 'Microsoft Corporation CEO'},
{'아이디' : '@Carl_C_Icahn', '주식기호' : 'IEP', '이름' : 'Carl Icahn', '내용' : 'Icahn Enterprises LP CEO'},
{'아이디' : '@LisaSu', '주식기호' : 'AMD', '이름' : 'Mark Cuban', '내용' : 'AMD CEO'},
{'아이디' : '@levie', '주식기호' : 'BOX', '이름' : 'Aaron Levie', '내용' : 'BOX CEO'},
{'아이디' : '@bchesky', '주식기호' : 'ABNB', '이름' : 'Brian Chesky', '내용' : 'Airbnb CEO'}] 
# ABNB는 2020.12 부터 있음(상장)

# %%
stock_merge_df = []
for i in ceo_list:
    id_i = i['아이디']
    # print(id_i)
    ticker_i = i['주식기호']
    stock_df = pd.read_csv(r'C:\Users\mit16\Desktop\project\TeamProject_CodeWarrior\CodeWarrior_proj\dataSet\stock/'+ticker_i+'.csv')
    stock_df.insert(1, 'name', id_i)
    # print(stock_df)
    stock_merge_df.append(stock_df)
stock_merge_df = pd.concat(stock_merge_df)
stock_merge_df.rename(columns={'Adj Close': 'AdjClose'}, inplace=True)
stock_merge_df
# Out:
#            Date           name        Open        High         Low  \
# 0    2019-03-11  @reedhastings  352.000000  358.980011  350.029999
# 1    2019-03-12  @reedhastings  359.369995  360.130005  353.799988
# 2    2019-03-13  @reedhastings  355.809998  362.480011  352.769989
# 3    2019-03-14  @reedhastings  360.500000  363.839996  358.100006
# 4    2019-03-15  @reedhastings  361.019989  364.000000  358.890015
# ..          ...            ...         ...         ...         ...
# 809  2024-03-04       @bchesky  159.899994  163.014999  157.929993
# 810  2024-03-05       @bchesky  157.199997  159.979996  156.139999
# 811  2024-03-06       @bchesky  160.100006  164.589996  160.070007
# 812  2024-03-07       @bchesky  165.000000  165.384995  162.240005
# 813  2024-03-08       @bchesky  166.000000  168.190002  163.479996
#
#           Close    AdjClose   Volume
# 0    358.859985  358.859985  5387300
# 1    356.269989  356.269989  5164600
# 2    361.209991  361.209991  6444100
# 3    358.820007  358.820007  5271400
# 4    361.459991  361.459991  8444500
# ..          ...         ...      ...
# 809  158.089996  158.089996  4403200
# 810  159.330002  159.330002  4714300
# 811  163.869995  163.869995  5167900
# 812  163.539993  163.539993  3810300
# 813  164.910004  164.910004  4103600
#
# [12145 rows x 8 columns]

# %%
stock_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12145 entries, 0 to 813
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      12145 non-null  object
#  1   name      12145 non-null  object
#  2   Open      12145 non-null  float64
#  3   High      12145 non-null  float64
#  4   Low       12145 non-null  float64
#  5   Close     12145 non-null  float64
#  6   AdjClose  12145 non-null  float64
#  7   Volume    12145 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 853.9+ KB

# %%
stock_merge_df.to_csv('stock_merge_df .csv', sep='\t', index=False)

# %%
from sqlalchemy import create_engine,types
import getpass
import oracledb
import cx_Oracle as oci
 

pw = getpass.getpass("Enter password: ")
connection = oracledb.connect(
    user="c##aaa",
    password="bbb",
    dsn="localhost/xe")

user="c##aaa",
password="bbb",
dsn="1521/xe"
 
engine = create_engine(f'oracle://{user}:{password}@{dsn}')


print("Successfully connect to OracleDB")

connection.autocommit = True

cursor = connection.cursor()


df_list = stock_merge_df.values.tolist()
# Out:
# Successfully connect to OracleDB

# %%
df_list
# Out:
# [['2019-03-11',
#   '@reedhastings',
#   352.0,
#   358.980011,
#   350.029999,
#   358.859985,
#   358.859985,
#   5387300],
#  ['2019-03-12',
#   '@reedhastings',
#   359.369995,
#   360.130005,
#   353.799988,
#   356.269989,
#   356.269989,
#   5164600],
#  ['2019-03-13',
#   '@reedhastings',
#   355.809998,
#   362.480011,
#   352.769989,
#   361.209991,
#   361.209991,
#   6444100],
#  ['2019-03-14',
#   '@reedhastings',
#   360.5,
#   363.839996,
#   358.100006,
#   358.820007,
#   358.820007,
#   5271400],
#  ['2019-03-15',
#   '@reedhastings',
#   361.019989,
#   364.0,
#   358.890015,
#   361.459991,
#   361.459991,
#   8444500],
#  ['2019-03-18',
#   '@reedhastings',
#   362.470001,
#   370.970001,
#   361.859985,
#   363.440002,
#   363.440002,
#   7194700],
#  ['2019-03-19',
#   '@reedhastings',
#   366.399994,
#   366.959991,
#   356.799988,
#   358.779999,
#   358.779999,
#   7541400],
#  ['2019-03-20',
#   '@reedhastings',
#   358.910004,
#   375.899994,
#   357.01001,
#   375.220001,
#   375.220001,
#   10917200],
#  ['2019-03-21',
#   '@reedhastings',
#   374.0,
#   379.0,
#   370.609985,
#   377.869995,
#   377.869995,
#   8544000],
#  ['2019-03-22',
#   '@reedhastings',
#   375.950012,
#   376.429993,
#   360.040009,
#   361.01001,
#   361.01001,
#   8661300],
#  ['2019-03-25',
#   '@reedhastings',
#   359.0,
#   367.040009,
#   357.440002,
#   366.230011,
#   366.230011,
#   8473800],
#  ['2019-03-26',
#   '@reedhastings',
#   367.869995,
#   368.380005,
#   358.019989,
#   359.970001,
#   359.970001,
#   7666500],
#  ['2019-03-27',
#   '@reedhastings',
#   361.0,
#   362.470001,
#   350.369995,
#   353.369995,
#   353.369995,
#   7852400],
#  ['2019-03-28',
#   '@reedhastings',
#   354.48999,
#   355.940002,
#   349.200012,
#   354.609985,
#   354.609985,
#   4361000],
#  ['2019-03-29',
#   '@reedhastings',
#   357.160004,
#   358.25,
#   353.709991,
#   356.559998,
#   356.559998,
#   4705600],
#  ['2019-04-01',
#   '@reedhastings',
#   359.0,
#   368.329987,
#   358.51001,
#   366.959991,
#   366.959991,
#   7036100],
#  ['2019-04-02',
#   '@reedhastings',
#   366.25,
#   368.420013,
#   362.220001,
#   367.720001,
#   367.720001,
#   5158700],
#  ['2019-04-03',
#   '@reedhastings',
#   369.26001,
#   373.410004,
#   366.190002,
#   369.75,
#   369.75,
#   5368900],
#  ['2019-04-04',
#   '@reedhastings',
#   370.070007,
#   372.049988,
#   362.399994,
#   367.880005,
#   367.880005,
#   4627300],
#  ['2019-04-05',
#   '@reedhastings',
#   369.0,
#   369.799988,
#   364.660004,
#   365.48999,
#   365.48999,
#   3905500],
#  ['2019-04-08',
#   '@reedhastings',
#   365.109985,
#   365.940002,
#   359.929993,
#   361.410004,
#   361.410004,
#   4653800],
#  ['2019-04-09',
#   '@reedhastings',
#   360.540009,
#   366.73999,
#   359.0,
#   364.709991,
#   364.709991,
#   5439200],
#  ['2019-04-10',
#   '@reedhastings',
#   365.790009,
#   368.850006,
#   362.25,
#   363.920013,
#   363.920013,
#   4545600],
#  ['2019-04-11',
#   '@reedhastings',
#   365.0,
#   370.119995,
#   360.809998,
#   367.649994,
#   367.649994,
#   6526900],
#  ['2019-04-12',
#   '@reedhastings',
#   360.690002,
#   361.75,
#   349.359985,
#   351.140015,
#   351.140015,
#   15646200],
#  ['2019-04-15',
#   '@reedhastings',
#   350.709991,
#   352.209991,
#   342.269989,
#   348.869995,
#   348.869995,
#   8842300],
#  ['2019-04-16',
#   '@reedhastings',
#   355.0,
#   364.480011,
#   352.720001,
#   359.459991,
#   359.459991,
#   18740200],
#  ['2019-04-17',
#   '@reedhastings',
#   365.049988,
#   368.76001,
#   350.600006,
#   354.73999,
#   354.73999,
#   18054100],
#  ['2019-04-18',
#   '@reedhastings',
#   355.0,
#   360.410004,
#   351.640015,
#   360.350006,
#   360.350006,
#   8353200],
#  ['2019-04-22',
#   '@reedhastings',
#   359.700012,
#   377.690002,
#   359.0,
#   377.339996,
#   377.339996,
#   11980500],
#  ['2019-04-23',
#   '@reedhastings',
#   375.450012,
#   384.799988,
#   374.709991,
#   381.890015,
#   381.890015,
#   10089800],
#  ['2019-04-24',
#   '@reedhastings',
#   381.070007,
#   381.899994,
#   373.269989,
#   374.230011,
#   374.230011,
#   6541900],
#  ['2019-04-25',
#   '@reedhastings',
#   374.48999,
#   374.76001,
#   365.700012,
#   368.329987,
#   368.329987,
#   6255500],
#  ['2019-04-26',
#   '@reedhastings',
#   368.350006,
#   375.140015,
#   366.23999,
#   374.850006,
#   374.850006,
#   5621900],
#  ['2019-04-29',
#   '@reedhastings',
#   373.679993,
#   374.579987,
#   369.119995,
#   371.829987,
#   371.829987,
#   3821700],
#  ['2019-04-30',
#   '@reedhastings',
#   369.559998,
#   374.5,
#   368.350006,
#   370.540009,
#   370.540009,
#   3870100],
#  ['2019-05-01',
#   '@reedhastings',
#   374.0,
#   385.98999,
#   373.170013,
#   378.809998,
#   378.809998,
#   9257300],
#  ['2019-05-02',
#   '@reedhastings',
#   378.0,
#   383.5,
#   374.51001,
#   379.059998,
#   379.059998,
#   5398200],
#  ['2019-05-03',
#   '@reedhastings',
#   381.529999,
#   385.029999,
#   378.269989,
#   385.029999,
#   385.029999,
#   5130300],
#  ['2019-05-06',
#   '@reedhastings',
#   377.690002,
#   381.350006,
#   376.0,
#   378.670013,
#   378.670013,
#   5793100],
#  ['2019-05-07',
#   '@reedhastings',
#   377.0,
#   379.910004,
#   365.809998,
#   370.459991,
#   370.459991,
#   6974900],
#  ['2019-05-08',
#   '@reedhastings',
#   367.920013,
#   369.0,
#   361.359985,
#   364.369995,
#   364.369995,
#   6572000],
#  ['2019-05-09',
#   '@reedhastings',
#   360.899994,
#   364.200012,
#   352.75,
#   362.75,
#   362.75,
#   5882600],
#  ['2019-05-10',
#   '@reedhastings',
#   361.619995,
#   365.26001,
#   353.059998,
#   361.040009,
#   361.040009,
#   5657100],
#  ['2019-05-13',
#   '@reedhastings',
#   352.290009,
#   354.26001,
#   343.100006,
#   345.26001,
#   345.26001,
#   8026700],
#  ['2019-05-14',
#   '@reedhastings',
#   348.709991,
#   349.950012,
#   342.5,
#   345.609985,
#   345.609985,
#   5353000],
#  ['2019-05-15',
#   '@reedhastings',
#   343.339996,
#   356.5,
#   341.390015,
#   354.98999,
#   354.98999,
#   6340100],
#  ['2019-05-16',
#   '@reedhastings',
#   356.369995,
#   364.0,
#   353.940002,
#   359.309998,
#   359.309998,
#   6441500],
#  ['2019-05-17',
#   '@reedhastings',
#   356.390015,
#   359.619995,
#   353.790009,
#   354.450012,
#   354.450012,
#   4725400],
#  ['2019-05-20',
#   '@reedhastings',
#   351.230011,
#   352.420013,
#   345.399994,
#   348.109985,
#   348.109985,
#   4621500],
#  ['2019-05-21',
#   '@reedhastings',
#   350.950012,
#   356.429993,
#   349.929993,
#   354.269989,
#   354.269989,
#   4026400],
#  ['2019-05-22',
#   '@reedhastings',
#   358.01001,
#   370.459991,
#   357.299988,
#   359.730011,
#   359.730011,
#   6229400],
#  ['2019-05-23',
#   '@reedhastings',
#   355.5,
#   357.420013,
#   347.700012,
#   352.209991,
#   352.209991,
#   5630400],
#  ['2019-05-24',
#   '@reedhastings',
#   355.410004,
#   359.440002,
#   353.790009,
#   354.390015,
#   354.390015,
#   3831000],
#  ['2019-05-28',
#   '@reedhastings',
#   354.390015,
#   361.200012,
#   353.649994,
#   355.059998,
#   355.059998,
#   4717100],
#  ['2019-05-29',
#   '@reedhastings',
#   353.600006,
#   353.850006,
#   345.899994,
#   349.190002,
#   349.190002,
#   5658900],
#  ['2019-05-30',
#   '@reedhastings',
#   350.549988,
#   354.209991,
#   348.299988,
#   351.850006,
#   351.850006,
#   4008000],
#  ['2019-05-31',
#   '@reedhastings',
#   347.220001,
#   349.339996,
#   342.920013,
#   343.279999,
#   343.279999,
#   5023400],
#  ['2019-06-03',
#   '@reedhastings',
#   343.559998,
#   347.660004,
#   332.649994,
#   336.630005,
#   336.630005,
#   7849600],
#  ['2019-06-04',
#   '@reedhastings',
#   345.0,
#   353.609985,
#   343.25,
#   353.399994,
#   353.399994,
#   7891600],
#  ['2019-06-05',
#   '@reedhastings',
#   354.380005,
#   357.880005,
#   348.709991,
#   355.730011,
#   355.730011,
#   5020100],
#  ['2019-06-06',
#   '@reedhastings',
#   354.839996,
#   358.209991,
#   352.089996,
#   357.130005,
#   357.130005,
#   3710000],
#  ['2019-06-07',
#   '@reedhastings',
#   357.390015,
#   365.149994,
#   355.690002,
#   360.869995,
#   360.869995,
#   4777300],
#  ['2019-06-10',
#   '@reedhastings',
#   363.649994,
#   367.100006,
#   349.290009,
#   352.01001,
#   352.01001,
#   7810300],
#  ['2019-06-11',
#   '@reedhastings',
#   355.0,
#   357.579987,
#   348.5,
#   351.269989,
#   351.269989,
#   5396700],
#  ['2019-06-12',
#   '@reedhastings',
#   351.820007,
#   353.609985,
#   343.230011,
#   345.559998,
#   345.559998,
#   4584700],
#  ['2019-06-13',
#   '@reedhastings',
#   347.230011,
#   348.5,
#   339.25,
#   343.429993,
#   343.429993,
#   6209300],
#  ['2019-06-14',
#   '@reedhastings',
#   341.630005,
#   343.399994,
#   336.160004,
#   339.730011,
#   339.730011,
#   5019000],
#  ['2019-06-17',
#   '@reedhastings',
#   342.690002,
#   351.769989,
#   342.059998,
#   350.619995,
#   350.619995,
#   5358200],
#  ['2019-06-18',
#   '@reedhastings',
#   355.570007,
#   361.5,
#   353.75,
#   357.119995,
#   357.119995,
#   5428500],
#  ['2019-06-19',
#   '@reedhastings',
#   361.720001,
#   364.73999,
#   356.119995,
#   363.519989,
#   363.519989,
#   5667200],
#  ['2019-06-20',
#   '@reedhastings',
#   365.910004,
#   370.119995,
#   361.220001,
#   365.209991,
#   365.209991,
#   5899500],
#  ['2019-06-21',
#   '@reedhastings',
#   365.0,
#   371.450012,
#   365.0,
#   369.209991,
#   369.209991,
#   7448400],
#  ['2019-06-24',
#   '@reedhastings',
#   370.269989,
#   375.0,
#   370.200012,
#   371.040009,
#   371.040009,
#   4830200],
#  ['2019-06-25',
#   '@reedhastings',
#   370.75,
#   371.0,
#   358.290009,
#   360.299988,
#   360.299988,
#   5750400],
#  ['2019-06-26',
#   '@reedhastings',
#   361.600006,
#   366.790009,
#   361.600006,
#   362.200012,
#   362.200012,
#   3669700],
#  ['2019-06-27',
#   '@reedhastings',
#   363.200012,
#   370.850006,
#   363.200012,
#   370.019989,
#   370.019989,
#   4138600],
#  ['2019-06-28',
#   '@reedhastings',
#   370.26001,
#   371.540009,
#   364.869995,
#   367.320007,
#   367.320007,
#   4592700],
#  ['2019-07-01',
#   '@reedhastings',
#   373.5,
#   376.660004,
#   372.0,
#   374.600006,
#   374.600006,
#   4992600],
#  ['2019-07-02',
#   '@reedhastings',
#   374.890015,
#   376.0,
#   370.309998,
#   375.429993,
#   375.429993,
#   3625000],
#  ['2019-07-03',
#   '@reedhastings',
#   376.690002,
#   381.98999,
#   375.839996,
#   381.720001,
#   381.720001,
#   3799000],
#  ['2019-07-05',
#   '@reedhastings',
#   378.290009,
#   381.399994,
#   375.559998,
#   380.549988,
#   380.549988,
#   3732200],
#  ['2019-07-08',
#   '@reedhastings',
#   378.190002,
#   378.25,
#   375.359985,
#   376.160004,
#   376.160004,
#   3113400],
#  ['2019-07-09',
#   '@reedhastings',
#   379.059998,
#   384.76001,
#   377.5,
#   379.929993,
#   379.929993,
#   6932800],
#  ['2019-07-10',
#   '@reedhastings',
#   382.769989,
#   384.339996,
#   362.679993,
#   381.0,
#   381.0,
#   5878800],
#  ['2019-07-11',
#   '@reedhastings',
#   381.100006,
#   384.540009,
#   378.799988,
#   379.5,
#   379.5,
#   4336300],
#  ['2019-07-12',
#   '@reedhastings',
#   378.679993,
#   379.73999,
#   372.790009,
#   373.25,
#   373.25,
#   6636900],
#  ['2019-07-15',
#   '@reedhastings',
#   372.940002,
#   373.679993,
#   362.299988,
#   366.600006,
#   366.600006,
#   7944700],
#  ['2019-07-16',
#   '@reedhastings',
#   370.089996,
#   371.339996,
#   364.920013,
#   365.98999,
#   365.98999,
#   5863200],
#  ['2019-07-17',
#   '@reedhastings',
#   366.25,
#   366.5,
#   361.75,
#   362.440002,
#   362.440002,
#   13639500],
#  ['2019-07-18',
#   '@reedhastings',
#   323.76001,
#   329.850006,
#   320.299988,
#   325.209991,
#   325.209991,
#   31287100],
#  ['2019-07-19',
#   '@reedhastings',
#   323.399994,
#   325.850006,
#   314.230011,
#   315.100006,
#   315.100006,
#   16302500],
#  ['2019-07-22',
#   '@reedhastings',
#   312.0,
#   314.540009,
#   305.809998,
#   310.619995,
#   310.619995,
#   17718000],
#  ['2019-07-23',
#   '@reedhastings',
#   311.440002,
#   313.5,
#   306.0,
#   307.299988,
#   307.299988,
#   9171100],
#  ['2019-07-24',
#   '@reedhastings',
#   310.51001,
#   319.98999,
#   307.25,
#   317.940002,
#   317.940002,
#   11961800],
#  ['2019-07-25',
#   '@reedhastings',
#   318.859985,
#   327.690002,
#   316.299988,
#   326.459991,
#   326.459991,
#   10798500],
#  ['2019-07-26',
#   '@reedhastings',
#   328.790009,
#   336.0,
#   327.5,
#   335.779999,
#   335.779999,
#   10847500],
#  ['2019-07-29',
#   '@reedhastings',
#   335.980011,
#   336.399994,
#   328.769989,
#   332.700012,
#   332.700012,
#   5782800],
#  ['2019-07-30',
#   '@reedhastings',
#   329.200012,
#   329.649994,
#   323.230011,
#   325.929993,
#   325.929993,
#   6029300],
#  ['2019-07-31',
#   '@reedhastings',
#   325.160004,
#   331.769989,
#   318.529999,
#   322.98999,
#   322.98999,
#   6259500],
#  ['2019-08-01',
#   '@reedhastings',
#   324.25,
#   328.579987,
#   318.73999,
#   319.5,
#   319.5,
#   6563200],
#  ['2019-08-02',
#   '@reedhastings',
#   317.48999,
#   319.410004,
#   311.799988,
#   318.829987,
#   318.829987,
#   6280300],
#  ['2019-08-05',
#   '@reedhastings',
#   310.959991,
#   313.420013,
#   304.679993,
#   307.630005,
#   307.630005,
#   8692500],
#  ['2019-08-06',
#   '@reedhastings',
#   310.579987,
#   311.880005,
#   305.299988,
#   310.100006,
#   310.100006,
#   6179100],
#  ['2019-08-07',
#   '@reedhastings',
#   302.559998,
#   305.0,
#   296.809998,
#   304.290009,
#   304.290009,
#   9322400],
#  ['2019-08-08',
#   '@reedhastings',
#   311.029999,
#   316.359985,
#   306.630005,
#   315.899994,
#   315.899994,
#   5905900],
#  ['2019-08-09',
#   '@reedhastings',
#   313.73999,
#   316.640015,
#   305.679993,
#   308.929993,
#   308.929993,
#   5349100],
#  ['2019-08-12',
#   '@reedhastings',
#   305.459991,
#   312.890015,
#   303.23999,
#   310.829987,
#   310.829987,
#   6531700],
#  ['2019-08-13',
#   '@reedhastings',
#   309.769989,
#   316.429993,
#   308.160004,
#   312.279999,
#   312.279999,
#   5289400],
#  ['2019-08-14',
#   '@reedhastings',
#   308.01001,
#   308.410004,
#   298.01001,
#   299.109985,
#   299.109985,
#   7355800],
#  ['2019-08-15',
#   '@reedhastings',
#   299.5,
#   300.630005,
#   288.0,
#   295.76001,
#   295.76001,
#   9629200],
#  ['2019-08-16',
#   '@reedhastings',
#   298.859985,
#   303.549988,
#   296.269989,
#   302.799988,
#   302.799988,
#   6905800],
#  ['2019-08-19',
#   '@reedhastings',
#   306.25,
#   311.75,
#   304.75,
#   309.380005,
#   309.380005,
#   4942200],
#  ['2019-08-20',
#   '@reedhastings',
#   304.570007,
#   305.0,
#   297.679993,
#   298.98999,
#   298.98999,
#   7349900],
#  ['2019-08-21',
#   '@reedhastings',
#   301.609985,
#   302.880005,
#   296.200012,
#   297.809998,
#   297.809998,
#   5685400],
#  ['2019-08-22',
#   '@reedhastings',
#   298.649994,
#   300.329987,
#   293.149994,
#   296.929993,
#   296.929993,
#   4974200],
#  ['2019-08-23',
#   '@reedhastings',
#   295.0,
#   299.01001,
#   290.320007,
#   291.440002,
#   291.440002,
#   6324900],
#  ['2019-08-26',
#   '@reedhastings',
#   295.23999,
#   296.950012,
#   292.5,
#   294.980011,
#   294.980011,
#   4695700],
#  ['2019-08-27',
#   '@reedhastings',
#   294.540009,
#   296.769989,
#   287.200012,
#   291.029999,
#   291.029999,
#   6309400],
#  ['2019-08-28',
#   '@reedhastings',
#   289.470001,
#   292.820007,
#   287.75,
#   291.769989,
#   291.769989,
#   3955700],
#  ['2019-08-29',
#   '@reedhastings',
#   295.0,
#   299.929993,
#   294.98999,
#   296.779999,
#   296.779999,
#   4388500],
#  ['2019-08-30',
#   '@reedhastings',
#   298.779999,
#   298.940002,
#   290.850006,
#   293.75,
#   293.75,
#   4446400],
#  ['2019-09-03',
#   '@reedhastings',
#   290.820007,
#   293.899994,
#   288.059998,
#   289.290009,
#   289.290009,
#   3682800],
#  ['2019-09-04',
#   '@reedhastings',
#   291.25,
#   292.380005,
#   286.51001,
#   291.519989,
#   291.519989,
#   4652500],
#  ['2019-09-05',
#   '@reedhastings',
#   285.320007,
#   293.970001,
#   282.790009,
#   293.25,
#   293.25,
#   8966800],
#  ['2019-09-06',
#   '@reedhastings',
#   293.350006,
#   293.350006,
#   287.029999,
#   290.170013,
#   290.170013,
#   5166600],
#  ['2019-09-09',
#   '@reedhastings',
#   294.809998,
#   301.549988,
#   290.600006,
#   294.339996,
#   294.339996,
#   8232700],
#  ['2019-09-10',
#   '@reedhastings',
#   291.160004,
#   297.170013,
#   282.660004,
#   287.98999,
#   287.98999,
#   12320200],
#  ['2019-09-11',
#   '@reedhastings',
#   285.700012,
#   292.649994,
#   284.609985,
#   288.269989,
#   288.269989,
#   7405900],
#  ['2019-09-12',
#   '@reedhastings',
#   288.100006,
#   292.730011,
#   286.600006,
#   288.859985,
#   288.859985,
#   5010900],
#  ['2019-09-13',
#   '@reedhastings',
#   290.609985,
#   296.619995,
#   290.040009,
#   294.149994,
#   294.149994,
#   6583100],
#  ['2019-09-16',
#   '@reedhastings',
#   294.230011,
#   297.429993,
#   289.779999,
#   294.290009,
#   294.290009,
#   5307400],
#  ['2019-09-17',
#   '@reedhastings',
#   294.5,
#   299.149994,
#   291.790009,
#   298.600006,
#   298.600006,
#   4777100],
#  ['2019-09-18',
#   '@reedhastings',
#   294.98999,
#   296.049988,
#   287.450012,
#   291.559998,
#   291.559998,
#   7811100],
#  ['2019-09-19',
#   '@reedhastings',
#   291.559998,
#   293.809998,
#   283.399994,
#   286.600006,
#   286.600006,
#   8461300],
#  ['2019-09-20',
#   '@reedhastings',
#   280.26001,
#   282.5,
#   266.0,
#   270.75,
#   270.75,
#   23832800],
#  ['2019-09-23',
#   '@reedhastings',
#   268.350006,
#   273.390015,
#   261.890015,
#   265.920013,
#   265.920013,
#   13478600],
#  ['2019-09-24',
#   '@reedhastings',
#   262.5,
#   265.0,
#   252.279999,
#   254.589996,
#   254.589996,
#   16338200],
#  ['2019-09-25',
#   '@reedhastings',
#   255.710007,
#   266.600006,
#   253.699997,
#   264.75,
#   264.75,
#   11643800],
#  ['2019-09-26',
#   '@reedhastings',
#   266.420013,
#   268.049988,
#   260.200012,
#   263.309998,
#   263.309998,
#   7684000],
#  ['2019-09-27',
#   '@reedhastings',
#   266.179993,
#   267.440002,
#   260.390015,
#   263.079987,
#   263.079987,
#   7328300],
#  ['2019-09-30',
#   '@reedhastings',
#   264.0,
#   268.880005,
#   262.779999,
#   267.619995,
#   267.619995,
#   6727200],
#  ['2019-10-01',
#   '@reedhastings',
#   267.350006,
#   272.200012,
#   264.029999,
#   269.579987,
#   269.579987,
#   8650300],
#  ['2019-10-02',
#   '@reedhastings',
#   263.609985,
#   269.350006,
#   262.190002,
#   268.029999,
#   268.029999,
#   7659100],
#  ['2019-10-03',
#   '@reedhastings',
#   267.779999,
#   268.839996,
#   257.01001,
#   268.149994,
#   268.149994,
#   8951000],
#  ['2019-10-04',
#   '@reedhastings',
#   268.200012,
#   275.480011,
#   266.470001,
#   272.790009,
#   272.790009,
#   9890400],
#  ['2019-10-07',
#   '@reedhastings',
#   271.98999,
#   276.679993,
#   271.279999,
#   274.459991,
#   274.459991,
#   6525600],
#  ['2019-10-08',
#   '@reedhastings',
#   273.029999,
#   275.529999,
#   270.640015,
#   270.720001,
#   270.720001,
#   6276400],
#  ['2019-10-09',
#   '@reedhastings',
#   270.019989,
#   271.0,
#   264.570007,
#   267.529999,
#   267.529999,
#   6794400],
#  ['2019-10-10',
#   '@reedhastings',
#   265.970001,
#   280.529999,
#   265.029999,
#   280.480011,
#   280.480011,
#   10809100],
#  ['2019-10-11',
#   '@reedhastings',
#   284.799988,
#   287.869995,
#   282.339996,
#   282.929993,
#   282.929993,
#   8786100],
#  ['2019-10-14',
#   '@reedhastings',
#   283.929993,
#   286.929993,
#   282.0,
#   285.529999,
#   285.529999,
#   5513200],
#  ['2019-10-15',
#   '@reedhastings',
#   283.820007,
#   285.869995,
#   279.399994,
#   284.25,
#   284.25,
#   7685600],
#  ['2019-10-16',
#   '@reedhastings',
#   283.119995,
#   288.170013,
#   280.73999,
#   286.279999,
#   286.279999,
#   16175900],
#  ['2019-10-17',
#   '@reedhastings',
#   304.48999,
#   308.75,
#   288.299988,
#   293.350006,
#   293.350006,
#   38258900],
#  ['2019-10-18',
#   '@reedhastings',
#   289.359985,
#   290.899994,
#   273.359985,
#   275.299988,
#   275.299988,
#   23429900],
#  ['2019-10-21',
#   '@reedhastings',
#   272.890015,
#   279.940002,
#   269.0,
#   278.049988,
#   278.049988,
#   12599200],
#  ['2019-10-22',
#   '@reedhastings',
#   271.160004,
#   275.410004,
#   265.799988,
#   266.690002,
#   266.690002,
#   11802400],
#  ['2019-10-23',
#   '@reedhastings',
#   268.059998,
#   273.920013,
#   266.630005,
#   271.269989,
#   271.269989,
#   7133500],
#  ['2019-10-24',
#   '@reedhastings',
#   271.809998,
#   274.019989,
#   268.799988,
#   271.5,
#   271.5,
#   4827400],
#  ['2019-10-25',
#   '@reedhastings',
#   270.679993,
#   277.769989,
#   270.179993,
#   276.820007,
#   276.820007,
#   4747800],
#  ['2019-10-28',
#   '@reedhastings',
#   278.049988,
#   285.75,
#   277.350006,
#   281.859985,
#   281.859985,
#   6248400],
#  ['2019-10-29',
#   '@reedhastings',
#   281.869995,
#   284.410004,
#   277.549988,
#   281.209991,
#   281.209991,
#   4356200],
#  ['2019-10-30',
#   '@reedhastings',
#   284.339996,
#   293.48999,
#   283.0,
#   291.450012,
#   291.450012,
#   9345600],
#  ['2019-10-31',
#   '@reedhastings',
#   291.0,
#   291.450012,
#   284.779999,
#   287.410004,
#   287.410004,
#   5090000],
#  ['2019-11-01',
#   '@reedhastings',
#   288.700012,
#   289.119995,
#   283.019989,
#   286.809998,
#   286.809998,
#   5594300],
#  ['2019-11-04',
#   '@reedhastings',
#   288.0,
#   295.390015,
#   287.160004,
#   292.859985,
#   292.859985,
#   5566200],
#  ['2019-11-05',
#   '@reedhastings',
#   289.98999,
#   291.190002,
#   286.309998,
#   288.029999,
#   288.029999,
#   4062400],
#  ['2019-11-06',
#   '@reedhastings',
#   288.190002,
#   290.559998,
#   285.839996,
#   288.589996,
#   288.589996,
#   3438300],
#  ['2019-11-07',
#   '@reedhastings',
#   290.700012,
#   298.190002,
#   288.269989,
#   289.570007,
#   289.570007,
#   5928500],
#  ['2019-11-08',
#   '@reedhastings',
#   288.730011,
#   293.98999,
#   287.51001,
#   291.570007,
#   291.570007,
#   4509000],
#  ['2019-11-11',
#   '@reedhastings',
#   289.160004,
#   296.359985,
#   288.5,
#   294.179993,
#   294.179993,
#   3944300],
#  ['2019-11-12',
#   '@reedhastings',
#   295.320007,
#   295.350006,
#   288.700012,
#   292.01001,
#   292.01001,
#   5772800],
#  ['2019-11-13',
#   '@reedhastings',
#   291.029999,
#   293.410004,
#   281.140015,
#   283.109985,
#   283.109985,
#   9158900],
#  ['2019-11-14',
#   '@reedhastings',
#   283.25,
#   290.630005,
#   283.220001,
#   289.619995,
#   289.619995,
#   6529000],
#  ['2019-11-15',
#   '@reedhastings',
#   290.589996,
#   295.820007,
#   287.570007,
#   295.029999,
#   295.029999,
#   6333800],
#  ['2019-11-18',
#   '@reedhastings',
#   296.0,
#   304.98999,
#   293.279999,
#   302.570007,
#   302.570007,
#   8616600],
#  ['2019-11-19',
#   '@reedhastings',
#   304.01001,
#   305.670013,
#   298.519989,
#   302.600006,
#   302.600006,
#   5918000],
#  ['2019-11-20',
#   '@reedhastings',
#   301.01001,
#   308.25,
#   301.0,
#   305.160004,
#   305.160004,
#   5111800],
#  ['2019-11-21',
#   '@reedhastings',
#   306.0,
#   312.690002,
#   304.26001,
#   311.690002,
#   311.690002,
#   7488400],
#  ['2019-11-22',
#   '@reedhastings',
#   309.100006,
#   311.399994,
#   304.410004,
#   310.480011,
#   310.480011,
#   5970100],
#  ['2019-11-25',
#   '@reedhastings',
#   308.829987,
#   315.730011,
#   305.25,
#   315.549988,
#   315.549988,
#   7873900],
#  ['2019-11-26',
#   '@reedhastings',
#   315.0,
#   316.5,
#   311.690002,
#   312.48999,
#   312.48999,
#   5321000],
#  ['2019-11-27',
#   '@reedhastings',
#   313.929993,
#   316.820007,
#   312.75,
#   315.929993,
#   315.929993,
#   4096900],
#  ['2019-11-29',
#   '@reedhastings',
#   315.779999,
#   316.619995,
#   313.339996,
#   314.660004,
#   314.660004,
#   2411700],
#  ['2019-12-02',
#   '@reedhastings',
#   314.390015,
#   314.390015,
#   303.75,
#   309.98999,
#   309.98999,
#   6218800],
#  ['2019-12-03',
#   '@reedhastings',
#   302.220001,
#   307.359985,
#   301.880005,
#   306.160004,
#   306.160004,
#   4992800],
#  ['2019-12-04',
#   '@reedhastings',
#   308.429993,
#   308.429993,
#   303.269989,
#   304.320007,
#   304.320007,
#   3512100],
#  ['2019-12-05',
#   '@reedhastings',
#   305.269989,
#   306.480011,
#   298.809998,
#   302.859985,
#   302.859985,
#   4615500],
#  ['2019-12-06',
#   '@reedhastings',
#   304.700012,
#   307.850006,
#   302.600006,
#   307.350006,
#   307.350006,
#   4457800],
#  ['2019-12-09',
#   '@reedhastings',
#   307.350006,
#   311.48999,
#   302.440002,
#   302.5,
#   302.5,
#   5748400],
#  ['2019-12-10',
#   '@reedhastings',
#   296.119995,
#   298.940002,
#   292.019989,
#   293.119995,
#   293.119995,
#   10476100],
#  ['2019-12-11',
#   '@reedhastings',
#   294.48999,
#   299.429993,
#   294.200012,
#   298.929993,
#   298.929993,
#   5589800],
#  ['2019-12-12',
#   '@reedhastings',
#   295.670013,
#   299.170013,
#   295.059998,
#   298.440002,
#   298.440002,
#   4766600],
#  ['2019-12-13',
#   '@reedhastings',
#   298.5,
#   301.799988,
#   297.25,
#   298.5,
#   298.5,
#   3879700],
#  ['2019-12-16',
#   '@reedhastings',
#   300.850006,
#   305.709991,
#   298.630005,
#   304.209991,
#   304.209991,
#   4658900],
#  ['2019-12-17',
#   '@reedhastings',
#   307.359985,
#   316.799988,
#   306.600006,
#   315.480011,
#   315.480011,
#   10427100],
#  ['2019-12-18',
#   '@reedhastings',
#   316.26001,
#   325.359985,
#   315.600006,
#   320.799988,
#   320.799988,
#   11207400],
#  ['2019-12-19',
#   '@reedhastings',
#   324.5,
#   332.829987,
#   324.179993,
#   332.220001,
#   332.220001,
#   9822300],
#  ['2019-12-20',
#   '@reedhastings',
#   335.0,
#   338.0,
#   330.600006,
#   336.899994,
#   336.899994,
#   9914900],
#  ['2019-12-23',
#   '@reedhastings',
#   337.76001,
#   337.950012,
#   331.019989,
#   333.100006,
#   333.100006,
#   5765300],
#  ['2019-12-24',
#   '@reedhastings',
#   334.01001,
#   335.700012,
#   331.600006,
#   333.200012,
#   333.200012,
#   2019300],
#  ['2019-12-26',
#   '@reedhastings',
#   334.600006,
#   336.459991,
#   332.01001,
#   332.630005,
#   332.630005,
#   3589900],
#  ['2019-12-27',
#   '@reedhastings',
#   332.959991,
#   333.820007,
#   326.01001,
#   329.089996,
#   329.089996,
#   5036100],
#  ['2019-12-30',
#   '@reedhastings',
#   329.079987,
#   329.190002,
#   322.859985,
#   323.309998,
#   323.309998,
#   4311500],
#  ['2019-12-31',
#   '@reedhastings',
#   322.0,
#   324.920013,
#   321.089996,
#   323.570007,
#   323.570007,
#   3713300],
#  ['2020-01-02',
#   '@reedhastings',
#   326.100006,
#   329.980011,
#   324.779999,
#   329.809998,
#   329.809998,
#   4485800],
#  ['2020-01-03',
#   '@reedhastings',
#   326.779999,
#   329.859985,
#   325.529999,
#   325.899994,
#   325.899994,
#   3806900],
#  ['2020-01-06',
#   '@reedhastings',
#   323.119995,
#   336.359985,
#   321.200012,
#   335.829987,
#   335.829987,
#   5663100],
#  ['2020-01-07',
#   '@reedhastings',
#   336.470001,
#   336.700012,
#   330.299988,
#   330.75,
#   330.75,
#   4703200],
#  ['2020-01-08',
#   '@reedhastings',
#   331.48999,
#   342.700012,
#   331.049988,
#   339.26001,
#   339.26001,
#   7104500],
#  ['2020-01-09',
#   '@reedhastings',
#   342.0,
#   343.420013,
#   334.609985,
#   335.660004,
#   335.660004,
#   4709300],
#  ['2020-01-10',
#   '@reedhastings',
#   337.130005,
#   338.5,
#   327.269989,
#   329.049988,
#   329.049988,
#   4718300],
#  ['2020-01-13',
#   '@reedhastings',
#   331.799988,
#   340.850006,
#   331.51001,
#   338.920013,
#   338.920013,
#   6290000],
#  ['2020-01-14',
#   '@reedhastings',
#   344.399994,
#   345.380005,
#   335.519989,
#   338.690002,
#   338.690002,
#   7199400],
#  ['2020-01-15',
#   '@reedhastings',
#   338.679993,
#   343.170013,
#   336.600006,
#   339.070007,
#   339.070007,
#   5158000],
#  ['2020-01-16',
#   '@reedhastings',
#   343.5,
#   343.559998,
#   335.850006,
#   338.619995,
#   338.619995,
#   5016000],
#  ['2020-01-17',
#   '@reedhastings',
#   341.0,
#   341.570007,
#   337.380005,
#   339.670013,
#   339.670013,
#   6066500],
#  ['2020-01-21',
#   '@reedhastings',
#   340.0,
#   341.0,
#   332.589996,
#   338.109985,
#   338.109985,
#   14350300],
#  ['2020-01-22',
#   '@reedhastings',
#   332.549988,
#   336.299988,
#   323.600006,
#   326.0,
#   326.0,
#   21730000],
#  ['2020-01-23',
#   '@reedhastings',
#   326.040009,
#   349.880005,
#   325.01001,
#   349.600006,
#   349.600006,
#   18200300],
#  ['2020-01-24',
#   '@reedhastings',
#   348.459991,
#   359.850006,
#   345.880005,
#   353.160004,
#   353.160004,
#   17939700],
#  ['2020-01-27',
#   '@reedhastings',
#   345.950012,
#   351.899994,
#   341.019989,
#   342.880005,
#   342.880005,
#   7709500],
#  ['2020-01-28',
#   '@reedhastings',
#   345.880005,
#   352.399994,
#   342.779999,
#   348.519989,
#   348.519989,
#   6821600],
#  ['2020-01-29',
#   '@reedhastings',
#   349.0,
#   349.399994,
#   338.549988,
#   343.160004,
#   343.160004,
#   7643500],
#  ['2020-01-30',
#   '@reedhastings',
#   341.100006,
#   348.200012,
#   339.25,
#   347.73999,
#   347.73999,
#   5328100],
#  ['2020-01-31',
#   '@reedhastings',
#   347.390015,
#   347.390015,
#   340.980011,
#   345.089996,
#   345.089996,
#   5230000],
#  ['2020-02-03',
#   '@reedhastings',
#   347.23999,
#   359.630005,
#   346.279999,
#   358.0,
#   358.0,
#   6670600],
#  ['2020-02-04',
#   '@reedhastings',
#   361.0,
#   369.570007,
#   356.100006,
#   369.01001,
#   369.01001,
#   7161500],
#  ['2020-02-05',
#   '@reedhastings',
#   375.130005,
#   375.25,
#   362.299988,
#   369.670013,
#   369.670013,
#   6437000],
#  ['2020-02-06',
#   '@reedhastings',
#   369.600006,
#   371.549988,
#   362.51001,
#   366.950012,
#   366.950012,
#   3920400],
#  ['2020-02-07',
#   '@reedhastings',
#   365.040009,
#   371.799988,
#   363.570007,
#   366.769989,
#   366.769989,
#   4385200],
#  ['2020-02-10',
#   '@reedhastings',
#   365.0,
#   374.799988,
#   362.519989,
#   371.070007,
#   371.070007,
#   5294100],
#  ['2020-02-11',
#   '@reedhastings',
#   373.75,
#   378.109985,
#   369.720001,
#   373.690002,
#   373.690002,
#   4772900],
#  ['2020-02-12',
#   '@reedhastings',
#   377.179993,
#   380.619995,
#   375.880005,
#   380.01001,
#   380.01001,
#   4624800],
#  ['2020-02-13',
#   '@reedhastings',
#   376.959991,
#   385.369995,
#   376.51001,
#   381.399994,
#   381.399994,
#   4485400],
#  ['2020-02-14',
#   '@reedhastings',
#   381.470001,
#   385.149994,
#   379.429993,
#   380.399994,
#   380.399994,
#   3736300],
#  ['2020-02-18',
#   '@reedhastings',
#   379.299988,
#   389.540009,
#   379.190002,
#   387.779999,
#   387.779999,
#   5173900],
#  ['2020-02-19',
#   '@reedhastings',
#   388.119995,
#   392.950012,
#   384.899994,
#   386.190002,
#   386.190002,
#   4896400],
#  ['2020-02-20',
#   '@reedhastings',
#   386.559998,
#   389.700012,
#   376.679993,
#   386.0,
#   386.0,
#   4079400],
#  ['2020-02-21',
#   '@reedhastings',
#   385.329987,
#   387.320007,
#   377.899994,
#   380.070007,
#   380.070007,
#   3930100],
#  ['2020-02-24',
#   '@reedhastings',
#   364.76001,
#   372.820007,
#   361.0,
#   368.700012,
#   368.700012,
#   6936400],
#  ['2020-02-25',
#   '@reedhastings',
#   372.0,
#   375.649994,
#   357.720001,
#   360.089996,
#   360.089996,
#   6481200],
#  ['2020-02-26',
#   '@reedhastings',
#   366.309998,
#   382.0,
#   365.0,
#   379.23999,
#   379.23999,
#   8934100],
#  ['2020-02-27',
#   '@reedhastings',
#   371.459991,
#   391.559998,
#   370.600006,
#   371.709991,
#   371.709991,
#   10967700],
#  ['2020-02-28',
#   '@reedhastings',
#   364.209991,
#   376.769989,
#   356.799988,
#   369.029999,
#   369.029999,
#   11168600],
#  ['2020-03-02',
#   '@reedhastings',
#   373.109985,
#   381.359985,
#   364.5,
#   381.049988,
#   381.049988,
#   6997900],
#  ['2020-03-03',
#   '@reedhastings',
#   381.029999,
#   393.519989,
#   367.399994,
#   368.769989,
#   368.769989,
#   8364600],
#  ['2020-03-04',
#   '@reedhastings',
#   377.769989,
#   384.01001,
#   370.51001,
#   383.790009,
#   383.790009,
#   5487300],
#  ['2020-03-05',
#   '@reedhastings',
#   381.0,
#   391.399994,
#   368.640015,
#   372.779999,
#   372.779999,
#   8747000],
#  ['2020-03-06',
#   '@reedhastings',
#   367.700012,
#   371.309998,
#   356.850006,
#   368.970001,
#   368.970001,
#   8147200],
#  ['2020-03-09',
#   '@reedhastings',
#   343.859985,
#   357.470001,
#   341.720001,
#   346.48999,
#   346.48999,
#   7405500],
#  ['2020-03-10',
#   '@reedhastings',
#   356.429993,
#   364.540009,
#   347.850006,
#   364.130005,
#   364.130005,
#   7604400],
#  ['2020-03-11',
#   '@reedhastings',
#   358.920013,
#   362.980011,
#   344.790009,
#   349.920013,
#   349.920013,
#   6036000],
#  ['2020-03-12',
#   '@reedhastings',
#   326.5,
#   335.720001,
#   307.320007,
#   315.25,
#   315.25,
#   12071600],
#  ['2020-03-13',
#   '@reedhastings',
#   330.51001,
#   336.420013,
#   307.390015,
#   336.299988,
#   336.299988,
#   9458200],
#  ['2020-03-16',
#   '@reedhastings',
#   306.630005,
#   334.350006,
#   294.75,
#   298.839996,
#   298.839996,
#   10559900],
#  ['2020-03-17',
#   '@reedhastings',
#   306.190002,
#   322.899994,
#   290.25,
#   319.75,
#   319.75,
#   10013900],
#  ['2020-03-18',
#   '@reedhastings',
#   302.399994,
#   331.579987,
#   300.0,
#   315.470001,
#   315.470001,
#   12593600],
#  ['2020-03-19',
#   '@reedhastings',
#   324.329987,
#   348.51001,
#   316.820007,
#   332.029999,
#   332.029999,
#   10616000],
#  ['2020-03-20',
#   '@reedhastings',
#   342.309998,
#   350.48999,
#   332.0,
#   332.829987,
#   332.829987,
#   10853800],
#  ['2020-03-23',
#   '@reedhastings',
#   347.890015,
#   366.109985,
#   340.880005,
#   360.269989,
#   360.269989,
#   13449400],
#  ['2020-03-24',
#   '@reedhastings',
#   369.98999,
#   372.929993,
#   353.029999,
#   357.320007,
#   357.320007,
#   11638700],
#  ['2020-03-25',
#   '@reedhastings',
#   361.019989,
#   362.0,
#   339.170013,
#   342.390015,
#   342.390015,
#   8767200],
#  ['2020-03-26',
#   '@reedhastings',
#   344.0,
#   363.839996,
#   341.730011,
#   362.98999,
#   362.98999,
#   7229600],
#  ['2020-03-27',
#   '@reedhastings',
#   359.089996,
#   368.559998,
#   353.0,
#   357.119995,
#   357.119995,
#   7948800],
#  ['2020-03-30',
#   '@reedhastings',
#   363.0,
#   377.799988,
#   361.170013,
#   370.959991,
#   370.959991,
#   8622000],
#  ['2020-03-31',
#   '@reedhastings',
#   367.929993,
#   383.01001,
#   366.440002,
#   375.5,
#   375.5,
#   9366500],
#  ['2020-04-01',
#   '@reedhastings',
#   376.049988,
#   380.230011,
#   361.019989,
#   364.079987,
#   364.079987,
#   6672500],
#  ['2020-04-02',
#   '@reedhastings',
#   364.079987,
#   370.98999,
#   360.059998,
#   370.079987,
#   370.079987,
#   4592500],
#  ['2020-04-03',
#   '@reedhastings',
#   367.470001,
#   370.899994,
#   357.51001,
#   361.76001,
#   361.76001,
#   4860800],
#  ['2020-04-06',
#   '@reedhastings',
#   365.220001,
#   380.290009,
#   361.709991,
#   379.959991,
#   379.959991,
#   8183900],
#  ['2020-04-07',
#   '@reedhastings',
#   380.0,
#   381.329987,
#   369.339996,
#   372.279999,
#   372.279999,
#   7046400],
#  ['2020-04-08',
#   '@reedhastings',
#   374.01001,
#   378.390015,
#   368.309998,
#   371.119995,
#   371.119995,
#   6908900],
#  ['2020-04-09',
#   '@reedhastings',
#   371.059998,
#   372.100006,
#   363.029999,
#   370.720001,
#   370.720001,
#   7711300],
#  ['2020-04-13',
#   '@reedhastings',
#   371.309998,
#   400.51001,
#   367.700012,
#   396.720001,
#   396.720001,
#   11692900],
#  ['2020-04-14',
#   '@reedhastings',
#   397.5,
#   417.820007,
#   394.850006,
#   413.549988,
#   413.549988,
#   11581000],
#  ['2020-04-15',
#   '@reedhastings',
#   413.0,
#   434.980011,
#   412.25,
#   426.75,
#   426.75,
#   13561200],
#  ['2020-04-16',
#   '@reedhastings',
#   437.0,
#   449.519989,
#   431.609985,
#   439.170013,
#   439.170013,
#   16128700],
#  ['2020-04-17',
#   '@reedhastings',
#   431.0,
#   432.0,
#   414.700012,
#   422.959991,
#   422.959991,
#   12616300],
#  ['2020-04-20',
#   '@reedhastings',
#   435.170013,
#   444.48999,
#   430.559998,
#   437.48999,
#   437.48999,
#   12655800],
#  ['2020-04-21',
#   '@reedhastings',
#   444.769989,
#   447.0,
#   425.600006,
#   433.829987,
#   433.829987,
#   23177600],
#  ['2020-04-22',
#   '@reedhastings',
#   429.730011,
#   433.0,
#   413.0,
#   421.420013,
#   421.420013,
#   21084800],
#  ['2020-04-23',
#   '@reedhastings',
#   419.26001,
#   438.410004,
#   419.26001,
#   426.700012,
#   426.700012,
#   13952300],
#  ['2020-04-24',
#   '@reedhastings',
#   425.0,
#   427.170013,
#   415.880005,
#   424.98999,
#   424.98999,
#   8658900],
#  ['2020-04-27',
#   '@reedhastings',
#   425.0,
#   429.0,
#   420.839996,
#   421.380005,
#   421.380005,
#   6277500],
#  ['2020-04-28',
#   '@reedhastings',
#   419.98999,
#   421.0,
#   402.910004,
#   403.829987,
#   403.829987,
#   10101200],
#  ['2020-04-29',
#   '@reedhastings',
#   399.529999,
#   415.859985,
#   393.600006,
#   411.890015,
#   411.890015,
#   9693100],
#  ['2020-04-30',
#   '@reedhastings',
#   410.309998,
#   424.440002,
#   408.0,
#   419.850006,
#   419.850006,
#   7954000],
#  ['2020-05-01',
#   '@reedhastings',
#   415.100006,
#   427.970001,
#   411.730011,
#   415.269989,
#   415.269989,
#   8299900],
#  ['2020-05-04',
#   '@reedhastings',
#   417.779999,
#   428.540009,
#   414.869995,
#   428.149994,
#   428.149994,
#   7799100],
#  ['2020-05-05',
#   '@reedhastings',
#   427.559998,
#   431.0,
#   421.559998,
#   424.679993,
#   424.679993,
#   6286300],
#  ['2020-05-06',
#   '@reedhastings',
#   429.299988,
#   439.769989,
#   426.390015,
#   434.26001,
#   434.26001,
#   6660700],
#  ['2020-05-07',
#   '@reedhastings',
#   436.890015,
#   438.880005,
#   430.660004,
#   436.529999,
#   436.529999,
#   5641900],
#  ['2020-05-08',
#   '@reedhastings',
#   434.140015,
#   442.0,
#   433.640015,
#   435.549988,
#   435.549988,
#   5049300],
#  ['2020-05-11',
#   '@reedhastings',
#   436.329987,
#   444.890015,
#   435.559998,
#   440.519989,
#   440.519989,
#   5486000],
#  ['2020-05-12',
#   '@reedhastings',
#   442.0,
#   444.170013,
#   431.359985,
#   431.820007,
#   431.820007,
#   4598200],
#  ['2020-05-13',
#   '@reedhastings',
#   435.690002,
#   447.0,
#   427.269989,
#   438.269989,
#   438.269989,
#   7014600],
#  ['2020-05-14',
#   '@reedhastings',
#   444.899994,
#   452.380005,
#   432.820007,
#   441.950012,
#   441.950012,
#   9007500],
#  ['2020-05-15',
#   '@reedhastings',
#   440.700012,
#   455.0,
#   437.51001,
#   454.190002,
#   454.190002,
#   7244000],
#  ['2020-05-18',
#   '@reedhastings',
#   451.160004,
#   456.359985,
#   443.350006,
#   452.579987,
#   452.579987,
#   7773500],
#  ['2020-05-19',
#   '@reedhastings',
#   453.399994,
#   458.970001,
#   450.470001,
#   451.040009,
#   451.040009,
#   4810500],
#  ['2020-05-20',
#   '@reedhastings',
#   454.25,
#   455.809998,
#   444.0,
#   447.670013,
#   447.670013,
#   5607300],
#  ['2020-05-21',
#   '@reedhastings',
#   448.559998,
#   448.959991,
#   430.25,
#   436.25,
#   436.25,
#   9117300],
#  ['2020-05-22',
#   '@reedhastings',
#   437.0,
#   439.089996,
#   427.179993,
#   429.320007,
#   429.320007,
#   5422300],
#  ['2020-05-26',
#   '@reedhastings',
#   427.769989,
#   428.5,
#   413.140015,
#   414.769989,
#   414.769989,
#   7881100],
#  ['2020-05-27',
#   '@reedhastings',
#   410.380005,
#   420.019989,
#   397.859985,
#   419.890015,
#   419.890015,
#   10446300],
#  ['2020-05-28',
#   '@reedhastings',
#   417.23999,
#   422.369995,
#   411.5,
#   413.440002,
#   413.440002,
#   5655100],
#  ['2020-05-29',
#   '@reedhastings',
#   417.459991,
#   420.299988,
#   411.850006,
#   419.730011,
#   419.730011,
#   5254900],
#  ['2020-06-01',
#   '@reedhastings',
#   418.829987,
#   426.720001,
#   415.980011,
#   425.920013,
#   425.920013,
#   3743700],
#  ['2020-06-02',
#   '@reedhastings',
#   425.869995,
#   427.589996,
#   419.459991,
#   427.309998,
#   427.309998,
#   3494800],
#  ['2020-06-03',
#   '@reedhastings',
#   426.950012,
#   427.100006,
#   418.049988,
#   421.970001,
#   421.970001,
#   4316000],
#  ['2020-06-04',
#   '@reedhastings',
#   422.390015,
#   428.709991,
#   410.029999,
#   414.329987,
#   414.329987,
#   5410500],
#  ['2020-06-05',
#   '@reedhastings',
#   407.290009,
#   420.23999,
#   404.25,
#   419.600006,
#   419.600006,
#   5099600],
#  ['2020-06-08',
#   '@reedhastings',
#   416.0,
#   420.799988,
#   406.5,
#   419.48999,
#   419.48999,
#   5851500],
#  ['2020-06-09',
#   '@reedhastings',
#   421.649994,
#   434.730011,
#   420.309998,
#   434.049988,
#   434.049988,
#   6797000],
#  ['2020-06-10',
#   '@reedhastings',
#   436.0,
#   439.690002,
#   430.549988,
#   434.480011,
#   434.480011,
#   4896900],
#  ['2020-06-11',
#   '@reedhastings',
#   428.200012,
#   445.570007,
#   424.160004,
#   425.559998,
#   425.559998,
#   7462900],
#  ['2020-06-12',
#   '@reedhastings',
#   429.0,
#   434.059998,
#   412.450012,
#   418.070007,
#   418.070007,
#   6461100],
#  ['2020-06-15',
#   '@reedhastings',
#   421.399994,
#   426.48999,
#   415.420013,
#   425.5,
#   425.5,
#   4467900],
#  ['2020-06-16',
#   '@reedhastings',
#   425.76001,
#   437.959991,
#   425.179993,
#   436.130005,
#   436.130005,
#   5507900],
#  ['2020-06-17',
#   '@reedhastings',
#   441.820007,
#   450.459991,
#   439.220001,
#   447.769989,
#   447.769989,
#   6529600],
#  ['2020-06-18',
#   '@reedhastings',
#   448.730011,
#   452.76001,
#   442.799988,
#   449.869995,
#   449.869995,
#   4277600],
#  ['2020-06-19',
#   '@reedhastings',
#   449.119995,
#   453.970001,
#   445.600006,
#   453.720001,
#   453.720001,
#   5934500],
#  ['2020-06-22',
#   '@reedhastings',
#   455.01001,
#   468.589996,
#   454.209991,
#   468.040009,
#   468.040009,
#   6272100],
#  ['2020-06-23',
#   '@reedhastings',
#   466.5,
#   474.01001,
#   464.5,
#   466.26001,
#   466.26001,
#   5948400],
#  ['2020-06-24',
#   '@reedhastings',
#   468.540009,
#   472.359985,
#   454.0,
#   457.850006,
#   457.850006,
#   4826200],
#  ['2020-06-25',
#   '@reedhastings',
#   458.859985,
#   467.01001,
#   454.0,
#   465.910004,
#   465.910004,
#   4134500],
#  ['2020-06-26',
#   '@reedhastings',
#   466.390015,
#   468.029999,
#   442.23999,
#   443.399994,
#   443.399994,
#   6804700],
#  ['2020-06-29',
#   '@reedhastings',
#   445.230011,
#   447.670013,
#   432.140015,
#   447.23999,
#   447.23999,
#   4844000],
#  ['2020-06-30',
#   '@reedhastings',
#   450.019989,
#   457.589996,
#   447.0,
#   455.040009,
#   455.040009,
#   4198500],
#  ['2020-07-01',
#   '@reedhastings',
#   454.0,
#   488.230011,
#   454.0,
#   485.640015,
#   485.640015,
#   9705900],
#  ['2020-07-02',
#   '@reedhastings',
#   485.640015,
#   492.279999,
#   475.529999,
#   476.890015,
#   476.890015,
#   6351500],
#  ['2020-07-06',
#   '@reedhastings',
#   480.769989,
#   499.5,
#   479.799988,
#   493.809998,
#   493.809998,
#   7839000],
#  ['2020-07-07',
#   '@reedhastings',
#   497.309998,
#   504.820007,
#   490.829987,
#   493.160004,
#   493.160004,
#   5669900],
#  ['2020-07-08',
#   '@reedhastings',
#   498.579987,
#   505.100006,
#   493.809998,
#   502.779999,
#   502.779999,
#   5691700],
#  ['2020-07-09',
#   '@reedhastings',
#   508.399994,
#   510.0,
#   495.779999,
#   507.76001,
#   507.76001,
#   5840500],
#  ['2020-07-10',
#   '@reedhastings',
#   519.72998,
#   555.880005,
#   511.279999,
#   548.72998,
#   548.72998,
#   21605600],
#  ['2020-07-13',
#   '@reedhastings',
#   567.97998,
#   575.369995,
#   520.960022,
#   525.5,
#   525.5,
#   18399000],
#  ['2020-07-14',
#   '@reedhastings',
#   517.080017,
#   525.5,
#   490.48999,
#   524.880005,
#   524.880005,
#   15083300],
#  ['2020-07-15',
#   '@reedhastings',
#   516.299988,
#   529.0,
#   510.179993,
#   523.26001,
#   523.26001,
#   10066700],
#  ['2020-07-16',
#   '@reedhastings',
#   526.47998,
#   535.539978,
#   504.359985,
#   527.390015,
#   527.390015,
#   24499000],
#  ['2020-07-17',
#   '@reedhastings',
#   494.869995,
#   503.589996,
#   484.140015,
#   492.98999,
#   492.98999,
#   24991400],
#  ['2020-07-20',
#   '@reedhastings',
#   489.140015,
#   504.5,
#   484.200012,
#   502.410004,
#   502.410004,
#   11940300],
#  ['2020-07-21',
#   '@reedhastings',
#   506.0,
#   506.220001,
#   488.609985,
#   490.100006,
#   490.100006,
#   9113700],
#  ['2020-07-22',
#   '@reedhastings',
#   492.190002,
#   497.200012,
#   487.200012,
#   489.820007,
#   489.820007,
#   6954100],
#  ['2020-07-23',
#   '@reedhastings',
#   491.130005,
#   491.899994,
#   472.019989,
#   477.579987,
#   477.579987,
#   7722000],
#  ['2020-07-24',
#   '@reedhastings',
#   468.769989,
#   487.170013,
#   467.540009,
#   480.450012,
#   480.450012,
#   7746200],
#  ['2020-07-27',
#   '@reedhastings',
#   484.51001,
#   496.920013,
#   482.309998,
#   495.649994,
#   495.649994,
#   7863100],
#  ['2020-07-28',
#   '@reedhastings',
#   496.019989,
#   497.790009,
#   487.76001,
#   488.51001,
#   488.51001,
#   5986700],
#  ['2020-07-29',
#   '@reedhastings',
#   492.25,
#   494.920013,
#   484.130005,
#   484.480011,
#   484.480011,
#   6611800],
#  ['2020-07-30',
#   '@reedhastings',
#   480.709991,
#   488.350006,
#   477.51001,
#   485.799988,
#   485.799988,
#   6608600],
#  ['2020-07-31',
#   '@reedhastings',
#   488.290009,
#   494.799988,
#   484.5,
#   488.880005,
#   488.880005,
#   5916300],
#  ['2020-08-03',
#   '@reedhastings',
#   490.859985,
#   503.089996,
#   490.230011,
#   498.619995,
#   498.619995,
#   5873100],
#  ['2020-08-04',
#   '@reedhastings',
#   498.649994,
#   510.440002,
#   498.649994,
#   509.640015,
#   509.640015,
#   5608000],
#  ['2020-08-05',
#   '@reedhastings',
#   508.679993,
#   510.100006,
#   501.200012,
#   502.109985,
#   502.109985,
#   4308200],
#  ['2020-08-06',
#   '@reedhastings',
#   504.109985,
#   510.820007,
#   498.700012,
#   509.079987,
#   509.079987,
#   3725900],
#  ['2020-08-07',
#   '@reedhastings',
#   505.450012,
#   508.290009,
#   486.679993,
#   494.730011,
#   494.730011,
#   5910300],
#  ['2020-08-10',
#   '@reedhastings',
#   493.350006,
#   497.459991,
#   478.630005,
#   483.380005,
#   483.380005,
#   4691200],
#  ['2020-08-11',
#   '@reedhastings',
#   479.75,
#   480.920013,
#   466.549988,
#   466.929993,
#   466.929993,
#   7329200],
#  ['2020-08-12',
#   '@reedhastings',
#   471.339996,
#   482.48999,
#   470.179993,
#   475.470001,
#   475.470001,
#   5439200],
#  ['2020-08-13',
#   '@reedhastings',
#   478.399994,
#   484.450012,
#   476.450012,
#   481.329987,
#   481.329987,
#   3008900],
#  ['2020-08-14',
#   '@reedhastings',
#   482.820007,
#   488.329987,
#   480.209991,
#   482.679993,
#   482.679993,
#   2943500],
#  ['2020-08-17',
#   '@reedhastings',
#   484.190002,
#   486.23999,
#   479.100006,
#   482.350006,
#   482.350006,
#   2423500],
#  ['2020-08-18',
#   '@reedhastings',
#   484.350006,
#   495.299988,
#   482.799988,
#   491.869995,
#   491.869995,
#   3505500],
#  ['2020-08-19',
#   '@reedhastings',
#   493.929993,
#   494.5,
#   483.5,
#   484.529999,
#   484.529999,
#   3156200],
#  ['2020-08-20',
#   '@reedhastings',
#   484.690002,
#   498.940002,
#   483.890015,
#   497.899994,
#   497.899994,
#   5132500],
#  ['2020-08-21',
#   '@reedhastings',
#   496.459991,
#   498.130005,
#   490.0,
#   492.309998,
#   492.309998,
#   3921300],
#  ['2020-08-24',
#   '@reedhastings',
#   495.440002,
#   501.0,
#   483.160004,
#   488.809998,
#   488.809998,
#   4762200],
#  ['2020-08-25',
#   '@reedhastings',
#   488.190002,
#   492.470001,
#   485.089996,
#   490.579987,
#   490.579987,
#   5727700],
#  ['2020-08-26',
#   '@reedhastings',
#   492.5,
#   549.039978,
#   492.079987,
#   547.530029,
#   547.530029,
#   20373700],
#  ['2020-08-27',
#   '@reedhastings',
#   537.780029,
#   541.0,
#   521.25,
#   526.27002,
#   526.27002,
#   9062900],
#  ['2020-08-28',
#   '@reedhastings',
#   532.0,
#   539.0,
#   522.0,
#   523.890015,
#   523.890015,
#   4417500],
#  ['2020-08-31',
#   '@reedhastings',
#   521.159973,
#   531.98999,
#   517.580017,
#   529.559998,
#   529.559998,
#   4941400],
#  ['2020-09-01',
#   '@reedhastings',
#   532.599976,
#   557.390015,
#   532.450012,
#   556.549988,
#   556.549988,
#   9572700],
#  ['2020-09-02',
#   '@reedhastings',
#   553.780029,
#   556.5,
#   537.369995,
#   552.840027,
#   552.840027,
#   5886900],
#  ['2020-09-03',
#   '@reedhastings',
#   545.0,
#   554.0,
#   521.320007,
#   525.75,
#   525.75,
#   9071100],
#  ['2020-09-04',
#   '@reedhastings',
#   520.179993,
#   527.359985,
#   485.980011,
#   516.049988,
#   516.049988,
#   8270100],
#  ['2020-09-08',
#   '@reedhastings',
#   498.399994,
#   522.0,
#   495.0,
#   507.019989,
#   507.019989,
#   5572700],
#  ['2020-09-09',
#   '@reedhastings',
#   519.210022,
#   520.0,
#   492.570007,
#   500.190002,
#   500.190002,
#   6848100],
#  ['2020-09-10',
#   '@reedhastings',
#   503.350006,
#   506.290009,
#   478.839996,
#   480.670013,
#   480.670013,
#   6240200],
#  ['2020-09-11',
#   '@reedhastings',
#   486.48999,
#   493.730011,
#   476.809998,
#   482.029999,
#   482.029999,
#   5035200],
#  ['2020-09-14',
#   '@reedhastings',
#   480.619995,
#   488.98999,
#   471.299988,
#   476.26001,
#   476.26001,
#   7359100],
#  ['2020-09-15',
#   '@reedhastings',
#   484.0,
#   497.470001,
#   481.630005,
#   495.98999,
#   495.98999,
#   5337000],
#  ['2020-09-16',
#   '@reedhastings',
#   499.98999,
#   504.660004,
#   483.309998,
#   483.859985,
#   483.859985,
#   4394900],
#  ['2020-09-17',
#   '@reedhastings',
#   475.160004,
#   478.399994,
#   463.269989,
#   470.200012,
#   470.200012,
#   5379300],
#  ['2020-09-18',
#   '@reedhastings',
#   472.51001,
#   479.399994,
#   458.600006,
#   469.959991,
#   469.959991,
#   6717700],
#  ['2020-09-21',
#   '@reedhastings',
#   467.690002,
#   487.779999,
#   466.320007,
#   487.350006,
#   487.350006,
#   5457500],
#  ['2020-09-22',
#   '@reedhastings',
#   489.01001,
#   491.820007,
#   479.26001,
#   491.170013,
#   491.170013,
#   3482300],
#  ['2020-09-23',
#   '@reedhastings',
#   491.040009,
#   491.040009,
#   469.0,
#   470.609985,
#   470.609985,
#   3726400],
#  ['2020-09-24',
#   '@reedhastings',
#   470.529999,
#   477.0,
#   467.820007,
#   473.079987,
#   473.079987,
#   3727200],
#  ['2020-09-25',
#   '@reedhastings',
#   474.390015,
#   484.869995,
#   468.029999,
#   482.880005,
#   482.880005,
#   3769400],
#  ['2020-09-28',
#   '@reedhastings',
#   489.109985,
#   492.0,
#   477.880005,
#   490.649994,
#   490.649994,
#   4773500],
#  ['2020-09-29',
#   '@reedhastings',
#   489.5,
#   496.290009,
#   486.529999,
#   493.480011,
#   493.480011,
#   3541500],
#  ['2020-09-30',
#   '@reedhastings',
#   492.570007,
#   504.630005,
#   489.269989,
#   500.029999,
#   500.029999,
#   4634100],
#  ['2020-10-01',
#   '@reedhastings',
#   506.029999,
#   529.549988,
#   503.600006,
#   527.51001,
#   527.51001,
#   8153700],
#  ['2020-10-02',
#   '@reedhastings',
#   516.429993,
#   526.369995,
#   502.700012,
#   503.059998,
#   503.059998,
#   6071200],
#  ['2020-10-05',
#   '@reedhastings',
#   506.799988,
#   520.98999,
#   501.700012,
#   520.650024,
#   520.650024,
#   4088100],
#  ['2020-10-06',
#   '@reedhastings',
#   518.719971,
#   521.820007,
#   504.160004,
#   505.869995,
#   505.869995,
#   4199000],
#  ['2020-10-07',
#   '@reedhastings',
#   518.0,
#   536.48999,
#   515.820007,
#   534.659973,
#   534.659973,
#   7988700],
#  ['2020-10-08',
#   '@reedhastings',
#   533.47998,
#   535.0,
#   524.150024,
#   531.789978,
#   531.789978,
#   5386500],
#  ['2020-10-09',
#   '@reedhastings',
#   537.830017,
#   544.280029,
#   535.0,
#   539.440002,
#   539.440002,
#   4781300],
#  ['2020-10-12',
#   '@reedhastings',
#   548.809998,
#   551.809998,
#   538.23999,
#   539.809998,
#   539.809998,
#   5391100],
#  ['2020-10-13',
#   '@reedhastings',
#   540.559998,
#   557.650024,
#   537.200012,
#   554.090027,
#   554.090027,
#   5602500],
#  ['2020-10-14',
#   '@reedhastings',
#   562.609985,
#   572.48999,
#   541.0,
#   541.450012,
#   541.450012,
#   9499000],
#  ['2020-10-15',
#   '@reedhastings',
#   545.52002,
#   551.219971,
#   535.099976,
#   541.940002,
#   541.940002,
#   5113100],
#  ['2020-10-16',
#   '@reedhastings',
#   549.5,
#   554.330017,
#   530.030029,
#   530.789978,
#   530.789978,
#   6347400],
#  ['2020-10-19',
#   '@reedhastings',
#   537.070007,
#   541.799988,
#   525.380005,
#   530.719971,
#   530.719971,
#   7567500],
#  ['2020-10-20',
#   '@reedhastings',
#   528.140015,
#   533.780029,
#   522.26001,
#   525.419983,
#   525.419983,
#   10047200],
#  ['2020-10-21',
#   '@reedhastings',
#   501.029999,
#   506.850006,
#   488.25,
#   489.049988,
#   489.049988,
#   17405700],
#  ['2020-10-22',
#   '@reedhastings',
#   494.690002,
#   495.140015,
#   482.0,
#   485.230011,
#   485.230011,
#   6997900],
#  ['2020-10-23',
#   '@reedhastings',
#   488.109985,
#   490.059998,
#   481.350006,
#   488.279999,
#   488.279999,
#   4927900],
#  ['2020-10-26',
#   '@reedhastings',
#   487.029999,
#   496.820007,
#   478.899994,
#   488.23999,
#   488.23999,
#   6186100],
#  ['2020-10-27',
#   '@reedhastings',
#   490.01001,
#   490.48999,
#   482.929993,
#   488.929993,
#   488.929993,
#   3627200],
#  ['2020-10-28',
#   '@reedhastings',
#   486.359985,
#   494.0,
#   483.279999,
#   486.23999,
#   486.23999,
#   5992700],
#  ['2020-10-29',
#   '@reedhastings',
#   488.5,
#   513.900024,
#   479.339996,
#   504.209991,
#   504.209991,
#   11120700],
#  ['2020-10-30',
#   '@reedhastings',
#   502.01001,
#   505.880005,
#   472.209991,
#   475.73999,
#   475.73999,
#   7807900],
#  ['2020-11-02',
#   '@reedhastings',
#   478.869995,
#   486.299988,
#   475.0,
#   484.119995,
#   484.119995,
#   4408200],
#  ['2020-11-03',
#   '@reedhastings',
#   484.929993,
#   495.309998,
#   478.76001,
#   487.220001,
#   487.220001,
#   3690200],
#  ['2020-11-04',
#   '@reedhastings',
#   495.359985,
#   507.730011,
#   493.980011,
#   496.950012,
#   496.950012,
#   5137300],
#  ['2020-11-05',
#   '@reedhastings',
#   506.559998,
#   518.72998,
#   503.450012,
#   513.76001,
#   513.76001,
#   5372800],
#  ['2020-11-06',
#   '@reedhastings',
#   515.0,
#   515.210022,
#   502.51001,
#   514.72998,
#   514.72998,
# ...
#   233.490005,
#   10982100],
#  ['2022-08-09',
#   '@reedhastings',
#   231.619995,
#   232.199997,
#   224.649994,
#   229.940002,
#   229.940002,
#   6181200],
#  ['2022-08-10',
#   '@reedhastings',
#   236.990005,
#   244.539993,
#   236.600006,
#   244.110001,
#   244.110001,
#   9254800],
#  ['2022-08-11',
#   '@reedhastings',
#   244.679993,
#   251.619995,
#   241.509995,
#   242.699997,
#   242.699997,
#   8780100],
#  ['2022-08-12',
#   '@reedhastings',
#   244.809998,
#   249.410004,
#   243.759995,
#   249.300003,
#   249.300003,
#   6098500],
#  ['2022-08-15',
#   '@reedhastings',
#   248.110001,
#   251.990005,
#   247.509995,
#   249.110001,
#   249.110001,
#   6527400],
#  ['2022-08-16',
#   '@reedhastings',
#   247.160004,
#   249.289993,
#   244.029999,
#   245.690002,
#   245.690002,
#   5136800],
#  ['2022-08-17',
#   '@reedhastings',
#   241.179993,
#   244.240005,
#   237.559998,
#   241.149994,
#   241.149994,
#   5627200],
#  ['2022-08-18',
#   '@reedhastings',
#   241.960007,
#   246.479996,
#   239.279999,
#   245.169998,
#   245.169998,
#   5280400],
#  ['2022-08-19',
#   '@reedhastings',
#   240.949997,
#   243.289993,
#   235.679993,
#   241.160004,
#   241.160004,
#   7504700],
#  ['2022-08-22',
#   '@reedhastings',
#   232.550003,
#   233.479996,
#   224.589996,
#   226.539993,
#   226.539993,
#   8630100],
#  ['2022-08-23',
#   '@reedhastings',
#   226.460007,
#   229.899994,
#   224.300003,
#   224.550003,
#   224.550003,
#   5276900],
#  ['2022-08-24',
#   '@reedhastings',
#   225.660004,
#   234.100006,
#   223.940002,
#   229.610001,
#   229.610001,
#   5426300],
#  ['2022-08-25',
#   '@reedhastings',
#   230.240005,
#   234.160004,
#   229.0,
#   233.979996,
#   233.979996,
#   3766900],
#  ['2022-08-26',
#   '@reedhastings',
#   233.630005,
#   236.949997,
#   223.149994,
#   223.279999,
#   223.279999,
#   5349800],
#  ['2022-08-29',
#   '@reedhastings',
#   221.929993,
#   229.869995,
#   221.520004,
#   224.570007,
#   224.570007,
#   7109400],
#  ['2022-08-30',
#   '@reedhastings',
#   226.660004,
#   229.789993,
#   218.740005,
#   220.649994,
#   220.649994,
#   5740400],
#  ['2022-08-31',
#   '@reedhastings',
#   227.0,
#   233.880005,
#   223.429993,
#   223.559998,
#   223.559998,
#   8615900],
#  ['2022-09-01',
#   '@reedhastings',
#   220.720001,
#   230.369995,
#   219.470001,
#   230.039993,
#   230.039993,
#   7292900],
#  ['2022-09-02',
#   '@reedhastings',
#   231.029999,
#   233.880005,
#   225.039993,
#   226.110001,
#   226.110001,
#   8164900],
#  ['2022-09-06',
#   '@reedhastings',
#   225.589996,
#   226.850006,
#   214.690002,
#   218.389999,
#   218.389999,
#   7469000],
#  ['2022-09-07',
#   '@reedhastings',
#   220.210007,
#   229.330002,
#   218.270004,
#   228.960007,
#   228.960007,
#   8149300],
#  ['2022-09-08',
#   '@reedhastings',
#   224.160004,
#   228.740005,
#   221.300003,
#   227.440002,
#   227.440002,
#   6737400],
#  ['2022-09-09',
#   '@reedhastings',
#   229.619995,
#   234.779999,
#   229.619995,
#   233.570007,
#   233.570007,
#   6699600],
#  ['2022-09-12',
#   '@reedhastings',
#   233.610001,
#   239.490005,
#   233.369995,
#   236.529999,
#   236.529999,
#   6047400],
#  ['2022-09-13',
#   '@reedhastings',
#   226.5,
#   227.690002,
#   217.720001,
#   218.130005,
#   218.130005,
#   8000100],
#  ['2022-09-14',
#   '@reedhastings',
#   219.820007,
#   228.0,
#   215.800003,
#   224.119995,
#   224.119995,
#   8230300],
#  ['2022-09-15',
#   '@reedhastings',
#   230.470001,
#   242.289993,
#   229.100006,
#   235.380005,
#   235.380005,
#   19454100],
#  ['2022-09-16',
#   '@reedhastings',
#   231.220001,
#   241.360001,
#   227.830002,
#   240.130005,
#   240.130005,
#   18914200],
#  ['2022-09-19',
#   '@reedhastings',
#   245.050003,
#   245.25,
#   235.75,
#   243.630005,
#   243.630005,
#   17912400],
#  ['2022-09-20',
#   '@reedhastings',
#   240.369995,
#   250.490005,
#   239.660004,
#   242.850006,
#   242.850006,
#   16037400],
#  ['2022-09-21',
#   '@reedhastings',
#   242.669998,
#   248.300003,
#   236.679993,
#   236.869995,
#   236.869995,
#   9166800],
#  ['2022-09-22',
#   '@reedhastings',
#   235.350006,
#   240.5,
#   231.660004,
#   237.050003,
#   237.050003,
#   10018000],
#  ['2022-09-23',
#   '@reedhastings',
#   235.139999,
#   236.449997,
#   221.429993,
#   226.410004,
#   226.410004,
#   11207200],
#  ['2022-09-26',
#   '@reedhastings',
#   225.600006,
#   232.699997,
#   223.009995,
#   224.070007,
#   224.070007,
#   8234300],
#  ['2022-09-27',
#   '@reedhastings',
#   228.630005,
#   230.639999,
#   220.720001,
#   224.360001,
#   224.360001,
#   7762200],
#  ['2022-09-28',
#   '@reedhastings',
#   229.690002,
#   246.649994,
#   227.380005,
#   245.199997,
#   245.199997,
#   17579700],
#  ['2022-09-29',
#   '@reedhastings',
#   241.610001,
#   246.979996,
#   235.679993,
#   239.710007,
#   239.710007,
#   18994900],
#  ['2022-09-30',
#   '@reedhastings',
#   237.0,
#   242.440002,
#   233.259995,
#   235.440002,
#   235.440002,
#   11848600],
#  ['2022-10-03',
#   '@reedhastings',
#   237.850006,
#   241.539993,
#   232.850006,
#   239.039993,
#   239.039993,
#   8657400],
#  ['2022-10-04',
#   '@reedhastings',
#   244.839996,
#   245.800003,
#   233.25,
#   240.740005,
#   240.740005,
#   13925900],
#  ['2022-10-05',
#   '@reedhastings',
#   238.759995,
#   241.589996,
#   227.380005,
#   236.729996,
#   236.729996,
#   10825600],
#  ['2022-10-06',
#   '@reedhastings',
#   236.679993,
#   244.279999,
#   233.910004,
#   240.020004,
#   240.020004,
#   9188900],
#  ['2022-10-07',
#   '@reedhastings',
#   235.770004,
#   237.330002,
#   224.279999,
#   224.75,
#   224.75,
#   9806100],
#  ['2022-10-10',
#   '@reedhastings',
#   225.639999,
#   233.830002,
#   224.229996,
#   229.979996,
#   229.979996,
#   9991100],
#  ['2022-10-11',
#   '@reedhastings',
#   226.050003,
#   230.440002,
#   213.699997,
#   214.289993,
#   214.289993,
#   15282400],
#  ['2022-10-12',
#   '@reedhastings',
#   214.300003,
#   223.669998,
#   212.639999,
#   220.869995,
#   220.869995,
#   12952600],
#  ['2022-10-13',
#   '@reedhastings',
#   212.690002,
#   234.470001,
#   211.729996,
#   232.509995,
#   232.509995,
#   17505000],
#  ['2022-10-14',
#   '@reedhastings',
#   237.800003,
#   238.800003,
#   229.509995,
#   230.0,
#   230.0,
#   15293400],
#  ['2022-10-17',
#   '@reedhastings',
#   234.410004,
#   249.919998,
#   234.399994,
#   245.100006,
#   245.100006,
#   21057800],
#  ['2022-10-18',
#   '@reedhastings',
#   249.800003,
#   250.369995,
#   237.729996,
#   240.860001,
#   240.860001,
#   25776700],
#  ['2022-10-19',
#   '@reedhastings',
#   265.0,
#   279.299988,
#   262.660004,
#   272.380005,
#   272.380005,
#   46685300],
#  ['2022-10-20',
#   '@reedhastings',
#   272.779999,
#   278.380005,
#   266.380005,
#   268.160004,
#   268.160004,
#   17207100],
#  ['2022-10-21',
#   '@reedhastings',
#   268.950012,
#   290.75,
#   265.679993,
#   289.570007,
#   289.570007,
#   24889100],
#  ['2022-10-24',
#   '@reedhastings',
#   290.230011,
#   290.48999,
#   280.359985,
#   282.450012,
#   282.450012,
#   13326400],
#  ['2022-10-25',
#   '@reedhastings',
#   286.950012,
#   297.589996,
#   285.549988,
#   291.019989,
#   291.019989,
#   15100700],
#  ['2022-10-26',
#   '@reedhastings',
#   290.040009,
#   305.630005,
#   288.040009,
#   298.619995,
#   298.619995,
#   15714100],
#  ['2022-10-27',
#   '@reedhastings',
#   298.329987,
#   305.209991,
#   294.779999,
#   296.940002,
#   296.940002,
#   14612600],
#  ['2022-10-28',
#   '@reedhastings',
#   297.700012,
#   301.190002,
#   292.290009,
#   295.720001,
#   295.720001,
#   9960500],
#  ['2022-10-31',
#   '@reedhastings',
#   295.130005,
#   297.619995,
#   289.5,
#   291.880005,
#   291.880005,
#   7505100],
#  ['2022-11-01',
#   '@reedhastings',
#   296.170013,
#   299.700012,
#   286.420013,
#   286.75,
#   286.75,
#   6916400],
#  ['2022-11-02',
#   '@reedhastings',
#   286.399994,
#   287.329987,
#   272.839996,
#   273.0,
#   273.0,
#   10367600],
#  ['2022-11-03',
#   '@reedhastings',
#   271.25,
#   276.290009,
#   268.799988,
#   269.059998,
#   269.059998,
#   7057400],
#  ['2022-11-04',
#   '@reedhastings',
#   272.019989,
#   274.970001,
#   255.320007,
#   260.790009,
#   260.790009,
#   11124700],
#  ['2022-11-07',
#   '@reedhastings',
#   261.059998,
#   261.149994,
#   252.089996,
#   258.600006,
#   258.600006,
#   7927000],
#  ['2022-11-08',
#   '@reedhastings',
#   259.920013,
#   266.079987,
#   256.880005,
#   263.459991,
#   263.459991,
#   7683800],
#  ['2022-11-09',
#   '@reedhastings',
#   259.660004,
#   260.899994,
#   254.220001,
#   254.660004,
#   254.660004,
#   7266000],
#  ['2022-11-10',
#   '@reedhastings',
#   265.98999,
#   275.359985,
#   260.089996,
#   274.970001,
#   274.970001,
#   9667300],
#  ['2022-11-11',
#   '@reedhastings',
#   274.470001,
#   290.660004,
#   271.559998,
#   290.130005,
#   290.130005,
#   9573800],
#  ['2022-11-14',
#   '@reedhastings',
#   290.0,
#   311.0,
#   288.190002,
#   299.269989,
#   299.269989,
#   17978200],
#  ['2022-11-15',
#   '@reedhastings',
#   309.200012,
#   312.709991,
#   302.549988,
#   310.200012,
#   310.200012,
#   14626900],
#  ['2022-11-16',
#   '@reedhastings',
#   309.940002,
#   310.48999,
#   303.609985,
#   306.019989,
#   306.019989,
#   8038600],
#  ['2022-11-17',
#   '@reedhastings',
#   294.720001,
#   299.820007,
#   291.0,
#   295.279999,
#   295.279999,
#   9838200],
#  ['2022-11-18',
#   '@reedhastings',
#   297.329987,
#   298.0,
#   287.0,
#   287.980011,
#   287.980011,
#   8400100],
#  ['2022-11-21',
#   '@reedhastings',
#   291.0,
#   291.869995,
#   282.660004,
#   285.049988,
#   285.049988,
#   7256500],
#  ['2022-11-22',
#   '@reedhastings',
#   284.98999,
#   286.980011,
#   277.339996,
#   286.690002,
#   286.690002,
#   6245100],
#  ['2022-11-23',
#   '@reedhastings',
#   285.910004,
#   292.470001,
#   283.76001,
#   291.5,
#   291.5,
#   5919000],
#  ['2022-11-25',
#   '@reedhastings',
#   289.0,
#   289.209991,
#   284.170013,
#   285.540009,
#   285.540009,
#   3236000],
#  ['2022-11-28',
#   '@reedhastings',
#   284.0,
#   289.549988,
#   280.529999,
#   281.170013,
#   281.170013,
#   4703400],
#  ['2022-11-29',
#   '@reedhastings',
#   282.5,
#   282.959991,
#   275.940002,
#   280.959991,
#   280.959991,
#   5786900],
#  ['2022-11-30',
#   '@reedhastings',
#   281.369995,
#   308.26001,
#   280.410004,
#   305.529999,
#   305.529999,
#   16070100],
#  ['2022-12-01',
#   '@reedhastings',
#   303.98999,
#   319.799988,
#   303.029999,
#   316.950012,
#   316.950012,
#   14664900],
#  ['2022-12-02',
#   '@reedhastings',
#   310.48999,
#   321.98999,
#   310.0,
#   320.410004,
#   320.410004,
#   12690600],
#  ['2022-12-05',
#   '@reedhastings',
#   316.459991,
#   322.769989,
#   310.920013,
#   312.589996,
#   312.589996,
#   8423000],
#  ['2022-12-06',
#   '@reedhastings',
#   311.0,
#   313.220001,
#   303.130005,
#   305.559998,
#   305.559998,
#   7195400],
#  ['2022-12-07',
#   '@reedhastings',
#   306.5,
#   309.609985,
#   302.100006,
#   308.420013,
#   308.420013,
#   7821600],
#  ['2022-12-08',
#   '@reedhastings',
#   309.109985,
#   312.380005,
#   304.809998,
#   310.26001,
#   310.26001,
#   7205300],
#  ['2022-12-09',
#   '@reedhastings',
#   321.450012,
#   329.0,
#   319.519989,
#   320.01001,
#   320.01001,
#   14364000],
#  ['2022-12-12',
#   '@reedhastings',
#   320.0,
#   323.179993,
#   308.850006,
#   315.179993,
#   315.179993,
#   10148600],
#  ['2022-12-13',
#   '@reedhastings',
#   328.0,
#   332.720001,
#   317.200012,
#   320.339996,
#   320.339996,
#   10756400],
#  ['2022-12-14',
#   '@reedhastings',
#   318.970001,
#   324.709991,
#   314.420013,
#   317.829987,
#   317.829987,
#   7543300],
#  ['2022-12-15',
#   '@reedhastings',
#   302.119995,
#   303.390015,
#   286.549988,
#   290.410004,
#   290.410004,
#   17724600],
#  ['2022-12-16',
#   '@reedhastings',
#   288.76001,
#   294.720001,
#   288.700012,
#   290.709991,
#   290.709991,
#   14080000],
#  ['2022-12-19',
#   '@reedhastings',
#   289.730011,
#   292.25,
#   286.130005,
#   288.299988,
#   288.299988,
#   6163700],
#  ['2022-12-20',
#   '@reedhastings',
#   281.23999,
#   289.279999,
#   280.809998,
#   288.190002,
#   288.190002,
#   6918100],
#  ['2022-12-21',
#   '@reedhastings',
#   289.98999,
#   300.660004,
#   286.5,
#   297.959991,
#   297.959991,
#   6376200],
#  ['2022-12-22',
#   '@reedhastings',
#   298.089996,
#   298.880005,
#   290.809998,
#   297.75,
#   297.75,
#   7856200],
#  ['2022-12-23',
#   '@reedhastings',
#   296.179993,
#   298.459991,
#   291.910004,
#   294.959991,
#   294.959991,
#   4251100],
#  ['2022-12-27',
#   '@reedhastings',
#   293.190002,
#   293.570007,
#   282.130005,
#   284.170013,
#   284.170013,
#   5778100],
#  ['2022-12-28',
#   '@reedhastings',
#   281.920013,
#   285.190002,
#   273.410004,
#   276.880005,
#   276.880005,
#   5964400],
#  ['2022-12-29',
#   '@reedhastings',
#   283.179993,
#   295.5,
#   281.01001,
#   291.119995,
#   291.119995,
#   9588500],
#  ['2022-12-30',
#   '@reedhastings',
#   285.529999,
#   295.01001,
#   283.220001,
#   294.880005,
#   294.880005,
#   7566900],
#  ['2023-01-03',
#   '@reedhastings',
#   298.059998,
#   298.390015,
#   288.700012,
#   294.950012,
#   294.950012,
#   6764000],
#  ['2023-01-04',
#   '@reedhastings',
#   298.23999,
#   311.140015,
#   295.51001,
#   309.410004,
#   309.410004,
#   9345100],
#  ['2023-01-05',
#   '@reedhastings',
#   307.0,
#   314.179993,
#   304.549988,
#   309.700012,
#   309.700012,
#   8328400],
#  ['2023-01-06',
#   '@reedhastings',
#   311.570007,
#   316.769989,
#   303.690002,
#   315.549988,
#   315.549988,
#   8959800],
#  ['2023-01-09',
#   '@reedhastings',
#   316.829987,
#   321.700012,
#   313.220001,
#   315.170013,
#   315.170013,
#   6766600],
#  ['2023-01-10',
#   '@reedhastings',
#   311.070007,
#   329.350006,
#   311.070007,
#   327.540009,
#   327.540009,
#   13072300],
#  ['2023-01-11',
#   '@reedhastings',
#   326.5,
#   328.880005,
#   321.350006,
#   327.26001,
#   327.26001,
#   9579700],
#  ['2023-01-12',
#   '@reedhastings',
#   332.5,
#   332.950012,
#   323.140015,
#   330.130005,
#   330.130005,
#   10856200],
#  ['2023-01-13',
#   '@reedhastings',
#   329.970001,
#   336.649994,
#   328.890015,
#   332.820007,
#   332.820007,
#   8286800],
#  ['2023-01-17',
#   '@reedhastings',
#   331.079987,
#   332.5,
#   323.600006,
#   326.220001,
#   326.220001,
#   9247000],
#  ['2023-01-18',
#   '@reedhastings',
#   326.75,
#   330.079987,
#   321.25,
#   326.329987,
#   326.329987,
#   7814100],
#  ['2023-01-19',
#   '@reedhastings',
#   322.570007,
#   324.890015,
#   313.390015,
#   315.779999,
#   315.779999,
#   18008200],
#  ['2023-01-20',
#   '@reedhastings',
#   336.790009,
#   344.0,
#   332.630005,
#   342.5,
#   342.5,
#   28430300],
#  ['2023-01-23',
#   '@reedhastings',
#   341.720001,
#   362.25,
#   340.630005,
#   357.420013,
#   357.420013,
#   15646900],
#  ['2023-01-24',
#   '@reedhastings',
#   357.529999,
#   365.649994,
#   355.140015,
#   363.829987,
#   363.829987,
#   11796500],
#  ['2023-01-25',
#   '@reedhastings',
#   360.570007,
#   368.899994,
#   358.5,
#   367.959991,
#   367.959991,
#   7766900],
#  ['2023-01-26',
#   '@reedhastings',
#   368.769989,
#   369.019989,
#   361.700012,
#   364.869995,
#   364.869995,
#   8256800],
#  ['2023-01-27',
#   '@reedhastings',
#   363.200012,
#   365.920013,
#   360.589996,
#   360.769989,
#   360.769989,
#   6703500],
#  ['2023-01-30',
#   '@reedhastings',
#   358.440002,
#   360.950012,
#   352.859985,
#   353.109985,
#   353.109985,
#   5127600],
#  ['2023-01-31',
#   '@reedhastings',
#   349.980011,
#   355.950012,
#   348.709991,
#   353.859985,
#   353.859985,
#   5660700],
#  ['2023-02-01',
#   '@reedhastings',
#   353.859985,
#   365.390015,
#   349.910004,
#   361.98999,
#   361.98999,
#   8005200],
#  ['2023-02-02',
#   '@reedhastings',
#   365.160004,
#   368.320007,
#   358.429993,
#   366.890015,
#   366.890015,
#   7857000],
#  ['2023-02-03',
#   '@reedhastings',
#   359.079987,
#   379.429993,
#   359.0,
#   365.899994,
#   365.899994,
#   9402000],
#  ['2023-02-06',
#   '@reedhastings',
#   363.640015,
#   368.450012,
#   360.679993,
#   361.480011,
#   361.480011,
#   4994900],
#  ['2023-02-07',
#   '@reedhastings',
#   358.51001,
#   364.179993,
#   354.179993,
#   362.950012,
#   362.950012,
#   6289400],
#  ['2023-02-08',
#   '@reedhastings',
#   360.019989,
#   368.190002,
#   358.309998,
#   366.829987,
#   366.829987,
#   6253200],
#  ['2023-02-09',
#   '@reedhastings',
#   372.410004,
#   373.829987,
#   361.73999,
#   362.5,
#   362.5,
#   6901100],
#  ['2023-02-10',
#   '@reedhastings',
#   359.160004,
#   362.140015,
#   347.140015,
#   347.359985,
#   347.359985,
#   7291100],
#  ['2023-02-13',
#   '@reedhastings',
#   349.5,
#   359.700012,
#   344.25,
#   358.570007,
#   358.570007,
#   7134400],
#  ['2023-02-14',
#   '@reedhastings',
#   357.549988,
#   363.75,
#   353.399994,
#   359.959991,
#   359.959991,
#   4624800],
#  ['2023-02-15',
#   '@reedhastings',
#   356.630005,
#   362.880005,
#   354.23999,
#   361.420013,
#   361.420013,
#   3966000],
#  ['2023-02-16',
#   '@reedhastings',
#   355.0,
#   361.5,
#   350.309998,
#   350.709991,
#   350.709991,
#   5215700],
#  ['2023-02-17',
#   '@reedhastings',
#   347.910004,
#   349.0,
#   342.440002,
#   347.959991,
#   347.959991,
#   5294700],
#  ['2023-02-21',
#   '@reedhastings',
#   342.850006,
#   344.130005,
#   336.420013,
#   337.5,
#   337.5,
#   5710300],
#  ['2023-02-22',
#   '@reedhastings',
#   337.5,
#   341.910004,
#   332.820007,
#   334.880005,
#   334.880005,
#   4546200],
#  ['2023-02-23',
#   '@reedhastings',
#   331.230011,
#   331.279999,
#   314.299988,
#   323.649994,
#   323.649994,
#   13238700],
#  ['2023-02-24',
#   '@reedhastings',
#   319.299988,
#   321.5,
#   314.519989,
#   317.149994,
#   317.149994,
#   6830700],
#  ['2023-02-27',
#   '@reedhastings',
#   323.869995,
#   330.0,
#   322.119995,
#   323.029999,
#   323.029999,
#   6142600],
#  ...]

# %%
cursor.execute('INSERT INTO STOCKTBL VALUES (1,1,1,1,1,1,1,1)')

# %%
# CREATE TABLE
cursor.execute('create table stocktbl("Date" DATE,"name" VARCHAR(30),"Open" FLOAT,"High" FLOAT,"Low" FLOAT,"Close" FLOAT,"AdjClose" FLOAT,"Volume" INT)')
 
# dataframe to oracle
# cursor.executemany('INSERT INTO stocktbl("Date","name","Open","High","Low","Close","AdjClose","Volume") VALUES (:1,:2,:3,:4,:5,:6,:7,:8)', df_list, batcherrors = True)
cursor.executemany("INSERT INTO stocktbl VALUES (:1, :2, :3, :4, :5, :6, :7, :8)", df_list)



# cursor.execute('commit')


# for error in cursor.getbatcherrors():
#     print("Error", error.message, "at row offset", error.offset)

# %%
connection.close()

# %%
stock = pd.read_csv('..\\dataSet\\stock\\TSLA.csv')
stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2019-03-11   18.901333   19.418667   18.700001   19.394667   19.394667
# 1     2019-03-12   19.099333   19.204666   18.737333   18.890667   18.890667
# 2     2019-03-13   18.926666   19.466000   18.846666   19.264000   19.264000
# 3     2019-03-14   19.496668   19.692667   19.219334   19.330667   19.330667
# 4     2019-03-15   18.900667   18.914667   18.293333   18.362000   18.362000
# ...          ...         ...         ...         ...         ...         ...
# 1254  2024-03-04  198.729996  199.750000  186.720001  188.139999  188.139999
# 1255  2024-03-05  183.050003  184.589996  177.570007  180.740005  180.740005
# 1256  2024-03-06  179.990005  181.580002  173.699997  176.539993  176.539993
# 1257  2024-03-07  174.350006  180.039993  173.699997  178.649994  178.649994
# 1258  2024-03-08  181.500000  182.729996  174.699997  175.339996  175.339996
#
#          Volume
# 0     110884500
# 1     112561500
# 2     102670500
# 3     106551000
# 4     221782500
# ...         ...
# 1254  134334900
# 1255  119660800
# 1256  107920900
# 1257  102129000
# 1258   85315300
#
# [1259 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
import warnings

# %%
stock_merge_df['Close'].plot
plt.show()

# %%
import pandas as pd
twtdf = pd.DataFrame(columns=['username', 'data', 'tweet', 'retweets', 'likes'])
twtdf
# Out:
# Empty DataFrame
# Columns: [username, data, tweet, retweets, likes]
# Index: []
